# %% [markdown]
# # PROJETO 1 - CLASSIFICADOR DE SENTIMENTO DO FILME JOKER
# __________________________________________________________________________________________________________________
#
# ### Alunos:
#
# Nome: Beatriz Cabral Fernandes
#
# Nome: Eduardo Ancona Mateus

# %% [markdown]
# ## 1. INTRODUÇÃO
#
# A proposta desse projeto é desenvolver um classificador que irá analisar como o público está reagindo ao premiado filme ***Joker***, do diretor *Todd Phillips*. Para isso, será utilizado como método o famoso algoritmo de Naive-Bayes.

# %% [markdown]
# ## 2. DESENVOLVIMENTO E METODOLOGIA
#
# A fim de simplificar a explicação do processo de desenvolvimento do projeto, ele será dividido em 6 etapas
#
# ### ETAPA 1 - Preparando o ambiente no Jupyter
#
# Nessa etapa, serão baixadas e importadas todas as bibliotecas relevantes para o código, bem como implementadas todas as funções a serem utilizadas

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

#Importando as bibliotecas
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle
from IPython.display import Image
import re
import matplotlib.pyplot as plt 
import numpy as np

#leitura de arquivo de texto com stopwords do dicionario portugues

with open('stopwords.txt','r') as arquivo:
    stopwords = arquivo.readlines()
#aqui é criada uma lista com as stopwords
stopwords = '\n'.join(stopwords).split()


#criando funcao de limpeza de caracteres
def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    #import string
    http = re.sub(r"http\S+", "", text)
    punctuation = '[! - . : ? ; / _ # ) ( , \ " = ー — % « - { } -]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, ' ', http)
    return text_subbed

# %% [markdown]
# ### ETAPA 2 - Autenticando no Twitter
#
# Conta: `@datascience_dudle`
#
#
# Nessa etapa será feita a autenticação no twitter, e posteriormente a coleta de tweets a partir de uma palavra chave. O código pode ser observado no arquivo [Projeto1_Obtenção_dos_tweets.ipynb](http://localhost:8888/notebooks/2%20Semestre%20-%20DP/CDADOS/P1_Cdados_BW/Projeto1_Obten%C3%A7%C3%A3o_dos_tweets.ipynb)

# %% [markdown]
# ____________
#
# ### ETAPA 3 - Escolha de um produto e coleta das mensagens
#
# No arquivo `Projeto1_Obtenção_dos_tweets.ipynb` foram coletados tweets relacionados ao filme ***Joker*** e salvos em na planilha do excel `Joker.xlsx`. Ao coletar os tweets com essa keyword, obtivemos 901 tweets para treinamento e 300 para teste. A seguir foi feita a leitura dos arquivos.

# %%
# Fazendo a leitura da planilha de treinamento
excel = pd.read_excel('Joker.xlsx', sheet_name='Treinamento')
excel_teste = pd.read_excel('Joker.xlsx', sheet_name='Teste')
#excel_teste.rename(columns={'Etiquetas':'Class_manual'}, inplace=True)

# %%
excel_teste.head()
# Out:
#                                          Treinamento  Etiquetas
# 0  rt @_dcbrasil: maior ato do cinema de 2019! \n...          1
# 1  eu ñ fui assistir joker no cinema aqui pq so t...          3
# 2  @dracoh8 @caiquecerq @mateuscrz098 @joker_bsa ...          5
# 3  @joker_bsa @mitofaztd @portalprior mas o prior...          5
# 4  rt @itzguk: kpopper atacando o bts por tudo e ...          5

# %% [markdown]
# ### ETAPA 4 - Classificação manual dos tweets
#
# Vale ressaltar que o foco desse estudo é analisar o sentimento dos tweets relacionados ao premiado filme ***Joker***.
# Desta forma, foram previamente estabelecidas 5 categorias para a classificação das mensagens:
#
# * `P` - ***Crítica positiva*** – se a mensagem transmitida é uma crítica positiva;
# * `N` - ***Crítica negativa*** – se a mensagem transmitida é uma crítica negativa;
# * `I` - ***Irrelevante*** – se a mensagem transmitida estiver no contexto proposto, mas não for relevante para análise;
# * `R` - ***Reação*** - se a mensagem transmitida trata-se de uma reação ou emoção em relação ao filme ou a uma cena;
# * `F` - ***Fora do contexto*** - se a mensagem transmitida esta fora do contexto proposto.
#
#
# Estabelecidas as categorias e selecionados os tweets, foi utilizada a base de treinamento, na qual as mensagens foram qualificadas manualmente no excel de acordo com a categoria mais adequada. Conforme mostra a tabela a seguir:

# %%
excel.loc[:,'Etiquetas'] = excel['Etiquetas'].astype('category')
excel.Etiquetas.cat.categories = ['P','N','I','R','F']
excel.head()
# Out:
#                                          Treinamento Etiquetas
# 0  mortos pelo regime genocida da china 100.000.0...         F
# 1  @thiago_joker tempos de quarentena, sei lá né ...         F
# 2  se o governador do rio de janeiro candidatar p...         F
# 3  @jillajeeva332 @yutheesh0011 @joker_rowdy @pok...         F
# 4  galera só pra relembrar os filmes da dc de mai...         I

# %%
#Grafico para observar a distribuição das categorias P,N,I,R,F

fig = plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
t1 = pd.Series(excel.Etiquetas).value_counts(True).sort_index()
t1.plot(kind='bar')
plt.title('F.rel por categoria base de Treinamento')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')


plt.subplot(1, 2, 2)
t2 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
t2.plot(kind='bar')
plt.title('F.rel por categoria base de Teste')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')

plt.show()

# %% [markdown]
# Acima, observa-se um número de tweets da categoria F muito grande em detrimento do resto das categorias. Por conta disso, vamos primeiro classificar os tweets em 2 principais categorias: como *Dentro do contexto (soma das categorias P,N,R e I)* ou *Fora do contexto (categoria F)*, a fim de minimizar o enviesamento do classificador.

# %%
excel = excel.apply(pd.Series.replace, to_replace=['P','N','I', 'R'] , value='D')
excel.head()
# Out:
#                                          Treinamento Etiquetas
# 0  mortos pelo regime genocida da china 100.000.0...         F
# 1  @thiago_joker tempos de quarentena, sei lá né ...         F
# 2  se o governador do rio de janeiro candidatar p...         F
# 3  @jillajeeva332 @yutheesh0011 @joker_rowdy @pok...         F
# 4  galera só pra relembrar os filmes da dc de mai...         D

# %%
excel_teste.loc[:,'Etiquetas'] = excel_teste['Etiquetas'].astype('category')
excel_teste.Etiquetas.cat.categories = ['P','N','I','R','F']
excel_teste = excel_teste.apply(pd.Series.replace, to_replace=['P','N','I', 'R'] , value='D')
excel_teste.head()
# Out:
#                                          Treinamento Etiquetas
# 0  rt @_dcbrasil: maior ato do cinema de 2019! \n...         D
# 1  eu ñ fui assistir joker no cinema aqui pq so t...         D
# 2  @dracoh8 @caiquecerq @mateuscrz098 @joker_bsa ...         F
# 3  @joker_bsa @mitofaztd @portalprior mas o prior...         F
# 4  rt @itzguk: kpopper atacando o bts por tudo e ...         F

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
t3 = pd.Series(excel.Etiquetas).value_counts(True).sort_index()
t3.plot(kind='bar')
plt.title('F.rel por categoria base de Treinamento')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')


plt.subplot(1, 2, 2)
t4 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
t4.plot(kind='bar')
plt.title('F.rel por categoria base de Teste')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')

plt.show()

# %% [markdown]
# ### ETAPA 5 - Montando o Classificador Naive-Bayes

# %% [markdown]
# ### Breve explicação de *Naive Bayes*
# O algoritmo de *Naive Bayes* é um classificador probabilístico baseado no teorema de Bayes, utilizado no processo de machine learning. O algoritmo supõe que uma característica independe da outra para acontecer, ou seja, mesmo na presença de uma característica particular em uma classe, isso não afeta na probabilidade de qualquer característica ocorrer. O teorema de bayes é escrito da seguinte forma:

# %% [markdown]
# ![title](img/bayes.png)

# %% [markdown]
# * $P(A)$ - Probabilidade a priori
# * $P(B)$ - Probilidade Total
# * $P(A|B)$ - posteriori
# * $P(B|A)$ - verossimilhanca
#
#
# Esse método será utilizado no projeto, uma vez que permite calcular a probabilidade de uma mensagem receber diferentes classificações, por exemplo, dado um tweet, assumindo que as palavras nele não tem nenhuma relação entre si.
#
# A partir do nosso modelo, poderíamos reescrever o teorema de bayes da seguinte forma:

# %% [markdown]
# # $P(C|P) = \frac{P(P|C).P(C)}{P(P)}$

# %% [markdown]
# A variável C é a classe variável que representa a categoria de um tweet, a partir das condições estabelecidas (probabilidade de ocorrência de uma palavra dada as condições). A variável P representa as palavras ocorridas nos tweets.
#
#
# P pode ser:

# %% [markdown]
# ![title](img/bayes2.png)

# %% [markdown]
# Substituindo P por cada uma das possíveis palavras, temos:

# %% [markdown]
# ![title](img/bayes3.png)

# %% [markdown]
# Nesse momento queremos classificar se um tweet está dentro ou fora do contexto do filme Joker. Para tanto é necessário analisar analisar as probabilidades.
#
#
# Ou seja, precisa decidir se:
#
# ## $P(Dentro do contexto|frase) > P(Fora do contexto|frase)$
#
#
#
# Utilizando o teorema de Bayes, temos:
#
# ## $P(D|frase) = \frac{P(frase|D)P(D)}{P(frase)}$
#
# e que:
#
# ## $P(F|frase) = \frac{P(frase|F)P(F)}{P(frase)}$
#
#
#
# Para implementar esse algoritmo, uma nova tabela deve ser criada com as palavras e suas respectivas frequências relativas em cada uma das categorias. Porém antes disso, deverá ser feita uma limpeza das mensagens, removendo pontuações e caracteres que não convém a análise.

# %%
# Verificando categorias do meu dataset
list(excel)
# Out:
# ['Treinamento', 'Etiquetas']

# %%
# Juntando todos os tweets da base de treinamento
texto_completo = cleanup(' '.join(excel.Treinamento)).split()
texto_limpo = [word for word in texto_completo if word not in stopwords]
texto_limpo
# Out:
# ['mortos',
#  'regime',
#  'genocida',
#  'china',
#  '100',
#  '000',
#  '000',
#  'pessoas',
#  'mortos',
#  'regime',
#  'genocida',
#  'bolsonaro',
#  '0',
#  'vão',
#  'pentear',
#  'macaco',
#  'esquerdista',
#  'retardo',
#  'mental',
#  'thiago',
#  'joker',
#  'tempos',
#  'quarentena',
#  'sei',
#  'lá',
#  'né',
#  'hahahahhahaha',
#  'governador',
#  'rio',
#  'janeiro',
#  'candidatar',
#  'presidente',
#  'faço',
#  'campanha',
#  'cara',
#  'único',
#  'agora',
#  'detonou',
#  'vivo',
#  'presidente',
#  'faz',
#  'política',
#  'nesse',
#  'momento',
#  'resolve',
#  'nada',
#  'jillajeeva332',
#  'yutheesh0011',
#  'joker',
#  'rowdy',
#  'pokkiri',
#  'gvan',
#  'tsuriya16',
#  'saranveriyan',
#  'gmfarook1',
#  'karthikbigil',
#  'teamthalapathy1',
#  'itz',
#  'pokkiri7',
#  'atha',
#  'maranthuta',
#  'namba',
#  'galera',
#  'pra',
#  'relembrar',
#  'filmes',
#  'dc',
#  'maior',
#  'bilheteria',
#  'japão🇯🇵',
#  'onde',
#  'estará',
#  'birdsofprey',
#  'tempo',
#  'dirá',
#  '1',
#  'joker$46',
#  '7m',
#  '2',
#  'constantine$24',
#  '5m',
#  '3',
#  'thedarkknightrises$24',
#  '1m',
#  '4',
#  'batmanvsuperman',
#  '$16',
#  '5m',
#  '5',
#  'suicidesquad',
#  '$15',
#  '6m',
#  '6',
#  'aquaman',
#  '$14',
#  '8m',
#  '7',
#  'thedarkknight',
#  '$14',
#  '5m',
#  '1',
#  '2',
#  'the',
#  'lem0s',
#  'leandro',
#  'peroni',
#  'frase',
#  'bem',
#  'joker',
#  'antes',
#  'matar',
#  'murray',
#  'marqueszero',
#  'marques',
#  'sendo',
#  'realista',
#  'apesar',
#  'gostar',
#  'desse',
#  'cenário',
#  'vai',
#  'foder',
#  'saúde',
#  'vai',
#  'foder',
#  'economia',
#  '19',
#  'the',
#  'dark',
#  'knight',
#  'assiste',
#  'toda',
#  'trilogia',
#  '2008',
#  'suspeita',
#  'pra',
#  'falar',
#  'pq',
#  'amo',
#  'tudo',
#  'envolve',
#  'universo',
#  'batman',
#  'cara',
#  'melhor',
#  'batman',
#  'melhor',
#  'joker',
#  'trailer',
#  'davialcolumbre',
#  'senadofederal',
#  'anastasia',
#  'defende',
#  'responsável',
#  'disseminar',
#  'mortal',
#  'viruschines',
#  'infectou',
#  'mundo',
#  'foda',
#  'dança',
#  'morte',
#  'isentoes2',
#  'falou',
#  'errado',
#  'falou',
#  'mineres',
#  'rsrs',
#  'finalmente',
#  'vou',
#  'assistir',
#  'joker',
#  'carai',
#  'nerdboomer',
#  'joker',
#  'ícone',
#  'incels',
#  'nerds',
#  'falando',
#  'verdade',
#  'matrix',
#  'estar',
#  'tempo',
#  'casa',
#  'fazer',
#  'bem',
#  'hoje',
#  'sonhei',
#  'fazer',
#  'sexo',
#  'joker',
#  'carlosskendrick',
#  'filha',
#  'joker',
#  '😂',
#  'dracoh8',
#  'caiquecerq',
#  'mateuscrz098',
#  'joker',
#  'bsa',
#  'crisayonara',
#  'sim',
#  'pra',
#  'saírem',
#  'babu',
#  'saiu',
#  'anterior',
#  'prq',
#  'pyong',
#  'nessa',
#  'semana',
#  'qualquer',
#  'sai',
#  'prq',
#  'daniel',
#  'sair',
#  'bate',
#  'volta',
#  'zeca1908',
#  'gabi',
#  'vai',
#  'estar',
#  'imune',
#  'rafa',
#  'vai',
#  'imunizar',
#  'anjo',
#  'flamengo',
#  'saudades',
#  '😂🤷\u200d♂️',
#  'joaocsoares88',
#  'thecrepitos',
#  'assistindo',
#  'ainda',
#  'pouco',
#  'drawn',
#  'mask',
#  'deveras',
#  'confuso',
#  'juliannevituri',
#  'louquíssimo',
#  'capeto',
#  'morrendo',
#  'ces',
#  'perceberam',
#  'joker',
#  '2019',
#  'ta',
#  'sempre',
#  'maquiagem',
#  'olho',
#  'esquerdo',
#  'borrada',
#  'dizem',
#  'sempre',
#  'choro',
#  'tristeza',
#  'lágrimas',
#  'saem',
#  'primeiro',
#  'olho',
#  'esquerdo',
#  'to',
#  'shokk',
#  'filme',
#  'desejo',
#  'sincero',
#  'todd',
#  'phillips',
#  'nunca',
#  'explicar',
#  'final',
#  'joker',
#  'bielzinww',
#  'passo',
#  'personagens',
#  "'batman",
#  'série',
#  "animada'",
#  'versão',
#  '3d',
#  'feita',
#  'diretor',
#  'arte',
#  "'god",
#  'of',
#  "war'",
#  'raff',
#  'grasseti',
#  'ficou',
#  'incrível',
#  'coringa',
#  'joker',
#  'harleyquinn',
#  'arlequina',
#  'nerdboomer',
#  'humm',
#  'gays',
#  'todos',
#  'pagos',
#  'fingir',
#  'sofrimento',
#  'blá',
#  'blá',
#  'blá',
#  'assistido',
#  'filme',
#  'joker',
#  'entendido',
#  'verdade',
#  'lá',
#  's0ciedade',
#  'nunca',
#  'dão',
#  'atenção',
#  '😡😡😡😭😭😭😭😭nunca',
#  'dão',
#  'atenção',
#  'mim',
#  'creverson',
#  'homem',
#  '34',
#  'hetero',
#  'foda',
#  'passou',
#  'cabeça',
#  'trocar',
#  'foto',
#  'perfil',
#  'siga',
#  'todos',
#  'fav',
#  'tuite',
#  'paz',
#  'bbb20',
#  'vida',
#  'futebol',
#  'brasileirao2020',
#  'sdv',
#  'mundial',
#  'gremio',
#  'esporte',
#  'tmj',
#  'hanking',
#  'bom',
#  'aves',
#  'joker',
#  'poker',
#  'joker',
#  'obra',
#  'arte',
#  'nao',
#  'jeito',
#  'atenção',
#  'prior',
#  'incorporou',
#  'joker',
#  'altura',
#  '1',
#  '70',
#  'idade',
#  '17',
#  'tamanho',
#  'pé',
#  '40',
#  'signo',
#  'touro',
#  'tatuagens',
#  '0',
#  'piercings',
#  '0',
#  'cor',
#  'fav',
#  'cinza',
#  'filme',
#  'fav',
#  'joker',
#  'comida',
#  'fav',
#  'strogonoff',
#  'bebida',
#  'fav',
#  'coca',
#  'cola',
#  'série',
#  'fav',
#  'supernatural',
#  'time',
#  'sport',
#  'real',
#  'madrid',
#  'paulo',
#  'genocida',
#  'sabe',
#  'nome',
#  'disse',
#  'indignação',
#  'seletiva',
#  'mutantbanditx',
#  'ñ',
#  'quero',
#  'amizade',
#  'pscipota',
#  'nível',
#  'joker',
#  'harley',
#  'tb',
#  'ñ',
#  'quero',
#  'dc',
#  'fez',
#  'kevyn',
#  'duart7',
#  'vou',
#  'pensar',
#  'amanhã',
#  'ainda',
#  'kkkj',
#  'natewithane',
#  'acho',
#  'improvável',
#  'macho',
#  'acho',
#  'punchline',
#  'pois',
#  'harley',
#  'tentando',
#  'matar',
#  'coringa',
#  'brigando',
#  'punch',
#  'punch',
#  'sei',
#  'pois',
#  'provavelmente',
#  'defendendo',
#  'joker',
#  'thwlrs',
#  'adrieli',
#  's',
#  'brasil',
#  'possui',
#  '23',
#  '102',
#  'km',
#  'fronteiras',
#  'sendo',
#  '15',
#  '735',
#  'km',
#  'terrestres',
#  '7',
#  '367',
#  'km',
#  'marítimas',
#  'ahahahahhahahahahah',
#  'novo',
#  'argumento',
#  'deu',
#  'brasil',
#  'fronteira',
#  'itália',
#  'dimensão',
#  'vendo',
#  'hobbs',
#  'and',
#  'shaw',
#  'milésima',
#  'vez',
#  'filme',
#  'macho',
#  'qualidade',
#  'soco',
#  'joker',
#  'santoos',
#  'm',
#  'toma',
#  'kit',
#  'island',
#  'joker',
#  'tá',
#  'imune',
#  'falasdobatima',
#  'ahnnn',
#  'nao',
#  'posso',
#  'fazê',
#  'nada',
#  'tô',
#  'ficando',
#  'velho',
#  'tô',
#  'acabado',
#  'pinto',
#  'sobe',
#  'preciso',
#  'fazê',
#  'alguma…',
#  'odiodobem',
#  'bolsonarosp',
#  'esquerda',
#  'amor',
#  'próximo',
#  'ocoringadobem',
#  'mandetta',
#  'outro',
#  'vendido',
#  'joker',
#  'salva',
#  'olhei',
#  'joker',
#  'cara',
#  'filme',
#  'foda',
#  'ver',
#  'joker',
#  'vida',
#  'joker',
#  'adrieli',
#  's',
#  'bolsonaro',
#  'convoca',
#  'povo',
#  'ruas',
#  'diz',
#  'pra',
#  'continuar',
#  'indo',
#  'missa',
#  'futebol',
#  'sim',
#  'sendo',
#  'irresponsável',
#  'suspeita',
#  'contágio',
#  'recusando',
#  'mostrar',
#  'testes',
#  'sai',
#  'ruas',
#  'cumprimentando',
#  'pessoas',
#  'chamou',
#  'ali',
#  'errado',
#  'sarfuuu',
#  'taroq',
#  'jamil',
#  'carbo',
#  'vitamina',
#  'vc',
#  'precisava',
#  'come',
#  'alguma',
#  'proteína',
#  'peixe',
#  'bife',
#  'frango',
#  'ovo',
#  'mal',
#  'faz',
#  'dracoh8',
#  'caiquecerq',
#  'mateuscrz098',
#  'joker',
#  'bsa',
#  'crisayonara',
#  'parece',
#  'verídico',
#  'joker',
#  'razão',
#  'pedroconforti',
#  'rick84261031',
#  'delucca',
#  'oatila',
#  'tenta',
#  'novo',
#  'nobre',
#  'asno',
#  'tava',
#  'procurando',
#  'filme',
#  'joker',
#  'pra',
#  'baixar',
#  'assistir',
#  'pai',
#  'tava',
#  'achando',
#  'site',
#  'takei',
#  'fodase',
#  'baixei',
#  'xvideos',
#  '👍',
#  'pessoas',
#  'ouvem',
#  'the',
#  'weeknd',
#  'lado',
#  'obscuro',
#  '😫',
#  'preferem',
#  'joker',
#  'parasite',
#  'porque',
#  'identificam',
#  'bue',
#  'filme',
#  '😔😔',
#  'vieiravictorrr',
#  'booooa',
#  'jogador',
#  'ai',
#  'vi',
#  'fodaaas',
#  'jafarmsd71',
#  'nallavanmemes',
#  'actorvijay',
#  'kingmakerthala0',
#  'nkpmuruga2',
#  'muruganajith46',
#  'itz',
#  'seeni',
#  'itz',
#  'rdx2',
#  'mrthanimai',
#  'v3',
#  'its',
#  'joker',
#  'ak',
#  '7…',
#  'ddsaldanha',
#  'danielzis1',
#  'melhor',
#  'la',
#  'ninguém',
#  'entende',
#  'piada',
#  'pq',
#  'filme',
#  'chama',
#  'joker',
#  'evita14305211',
#  'k',
#  'asco',
#  'le',
#  'parece',
#  'al',
#  'joker',
#  'thwlrs',
#  'adrieli',
#  's',
#  'serve',
#  'quiser',
#  'olha',
#  'google',
#  'filha',
#  'vc',
#  'ouviu',
#  'falar',
#  'vai',
#  'quer',
#  'n',
#  'posso',
#  'ir',
#  'igreja',
#  'orar',
#  'pegar',
#  'ônibus',
#  'lotado',
#  'neguinho',
#  'respirando',
#  'cangote',
#  'muita',
#  'lógica',
#  'né',
#  'michelm28450829',
#  'parece',
#  'joker',
#  'continua',
#  'cartaz',
#  'laguns',
#  'cinemas',
#  'japão🇯🇵',
#  'bom',
#  'sair',
#  'sessao',
#  'entrar',
#  'a…',
#  'samirsalimjr',
#  'well',
#  'the',
#  'joker',
#  'is',
#  'called',
#  'the',
#  'coringa',
#  'in',
#  'brazil',
#  'amigo',
#  'daí',
#  'salto',
#  'qje',
#  'fazer',
#  'nível',
#  'abstração…',
#  'urbnsprwl',
#  'joker',
#  'lucasmatheuste4',
#  'zelphgamer',
#  '20006artur',
#  'luisfvalenca',
#  'sim',
#  'sim',
#  'questão',
#  'pra',
#  'entende',
#  'mecanismo',
#  'matemático',
#  'impossível',
#  'distinguir',
#  'argumento',
#  'estruturado',
#  'argumento',
#  'autoridade',
#  'tipo',
#  'consegue',
#  'entender',
#  '😔',
#  'aloisiopjunior',
#  'ótima',
#  'solução',
#  '🇧🇷',
#  'saúde',
#  'longevidade',
#  'felicidade',
#  'presidente',
#  'bolsonaro',
#  '🇧🇷',
#  'caiquecerq',
#  'mateuscrz098',
#  'crisayonara',
#  'prior',
#  'babu',
#  'selfie',
#  'fã',
#  'harry',
#  '✌️',
#  'ambulante',
#  'photoshoot',
#  'encarna',
#  'mix',
#  'bowie',
#  'phoenix',
#  'joker',
#  'annawings',
#  'galerinha',
#  'cheirosa',
#  'desse',
#  'twitter',
#  'vem',
#  'ajudar',
#  'diploma',
#  'venha',
#  'gente',
#  'responde',
#  'questionáriozinho',
#  'aqui',
#  'sobre',
#  '…',
#  '“a',
#  'pior',
#  'parte',
#  'doença',
#  'mental',
#  'pessoas',
#  'esperam',
#  'comporte',
#  '”',
#  'joker',
#  'coringa',
#  'sincero65119332',
#  'manueladavila',
#  'típico',
#  'burgues',
#  'disfarçado',
#  'pobre',
#  '👏🏻👏🏻👏🏻👏🏻👏🏻',
#  'definição',
#  'perfeita',
#  'sadsagita',
#  'hqzonna',
#  'onde',
#  'vi',
#  'punch',
#  'vai',
#  'namorada',
#  'joker',
#  'ddsaldanha',
#  'congeminemos',
#  'gringa',
#  'joker',
#  'então',
#  'simplesmente',
#  'impossível',
#  'explicar',
#  'pro',
#  'povo',
#  'especial',
#  'perros',
#  'película',
#  '🐶',
#  'parte',
#  '8',
#  'perros',
#  'joker',
#  'fluffyfursday',
#  'dogsofinstagram',
#  'guasón',
#  'dogs',
#  'fluffyjellydog',
#  'anapoima',
#  'elbromas',
#  'fluffy',
#  'thelighthouse',
#  'onceuponatimeinhollywood',
#  'midsommar',
#  'a24',
#  'thatgirlfromcv',
#  'referência',
#  'joker',
#  'pais',
#  'vivem',
#  'áfrica',
#  'fiz',
#  'piada',
#  'vivo',
#  'estado',
#  'constante',
#  'sofrimento',
#  'also',
#  'just',
#  'joke',
#  'nada',
#  'haddaddebochado',
#  'jair',
#  'bolsonaro',
#  'deu',
#  'entrevista',
#  'sbt',
#  'ontem',
#  'defendendo',
#  'aglomerações',
#  'shoppings',
#  'igrejas',
#  'precisa',
#  'retirado',
#  'd…',
#  'expandindo',
#  'brincadeira',
#  'manda',
#  '4',
#  'filmes',
#  'significam',
#  'pra',
#  'marque',
#  '4',
#  's',
#  'pra',
#  'fazer',
#  'volta',
#  'futuro',
#  'cavaleiro',
#  'trevas',
#  'harry',
#  'potter',
#  'série',
#  'guerra',
#  'infinita',
#  'gordinha',
#  'thiago',
#  'joker',
#  'juliannevituri',
#  'rolandinho',
#  'steverogersoff',
#  'thalafanboy',
#  'marishpazhani',
#  'prabhuzeus',
#  'kdrajaan',
#  'sandiyarthala',
#  'mrthanimai',
#  'itz',
#  'rdx',
#  'autokaaran3',
#  'its',
#  'joker',
#  'ak',
#  '7',
#  'muruganajith46',
#  'agent',
#  '0f',
#  'asgard',
#  'valimairanjith',
#  'its',
#  'chutty',
#  'enda',
#  'dei',
#  '😂',
#  'vitória',
#  'online',
#  'hahahahah',
#  'quarentenou',
#  'emcasa',
#  'gcjoker',
#  'online',
#  'aulas',
#  'joker',
#  'zahir',
#  'amo',
#  'recíproco',
#  'tb',
#  'pq',
#  'sofrer',
#  'dá',
#  'joaovpaulino',
#  'filhowilhan',
#  'gc',
#  'joker',
#  'ma',
#  'theus76',
#  'isadoraccorrea',
#  'marca',
#  'desgraça',
#  'wela',
#  'joker',
#  'acha',
#  'bosss',
#  'rwanphilipe',
#  'joker',
#  'tá',
#  'doido',
#  'koe',
#  '🤦🏽\u200d♂️',
#  'milky',
#  'choco93',
#  'panda',
#  "''",
#  '3',
#  'joker',
#  'broken',
#  'face',
#  'originais',
#  '|',
#  'faça',
#  'encomenda',
#  'através',
#  'website',
#  'flaviodino',
#  'irresponsável',
#  'escolhe',
#  'brigar',
#  'governadores',
#  'pura',
#  'politicagem',
#  'vez',
#  'brigar',
#  'vírus',
#  'irresponsáve…',
#  'grisagregorio',
#  'cruzei',
#  'número',
#  'casos',
#  'confirmados',
#  'coronavírus',
#  'brasil',
#  'algumas',
#  'falas',
#  'presidente',
#  'república',
#  'pontuei',
#  'ain…',
#  'mohajeden',
#  'booskacolombien',
#  'ladjiclass',
#  'nowa',
#  'jr',
#  'nass',
#  'joker',
#  'braxasosa',
#  'vikingoschwartz',
#  'naveladam',
#  'giovani',
#  'santos',
#  'wela',
#  'joker',
#  'acha',
#  'g',
#  'marmac',
#  'lucasmatheuste4',
#  ...]

# %%
palavras_total = pd.Series(texto_limpo).value_counts()
palavras_total
# Out:
# joker            646
# pra              126
# filme             78
# fav               61
# 1                 58
# pessoas           54
# dia               48
# fazer             47
# vc                45
# coringa           42
# vai               40
# s                 40
# luisfvalenca      36
# ver               35
# tá                34
# vou               33
# the               32
# quarentena        32
# agora             31
# adrieli           29
# 2                 28
# 6                 28
# pq                28
# melhor            28
# mundo             26
# todos             26
# 4                 26
# tudo              26
# n                 25
# 0                 25
#                 ...
# olhei              1
# reverso            1
# gravíssima         1
# deixe              1
# marriage           1
# superporreta       1
# desenvolve         1
# ianmanzz           1
# dependem           1
# blogdonoblat       1
# sararmmartins      1
# shazam             1
# terapia            1
# adei               1
# julho              1
# taesplendida       1
# matty              1
# castigar           1
# po                 1
# fii                1
# fina               1
# sucodm             1
# bolsanaro          1
# rubiasilva061      1
# fudendo            1
# giobarrera503      1
# dna                1
# jogos              1
# saga               1
# lendaria           1
# Length: 4735, dtype: int64

# %%
print('Número de palavras diferentes na base de treinamento inteira:', len(palavras_total))
# Out:
# Número de palavras diferentes na base de treinamento inteira: 4735

# %% [markdown]
# Fazendo uma breve análise dos 15 termos mais frequentes, observa-se que alguns desses termos não são significantes para a nossa análise, e portanto deve-se ser feita a limpeza para nao prejudicar o resultado/performance. Exemplo:
# - https
# - -
# - rt
# - /
# - @

# %%
def Frequencia(n):
    texto_completo = cleanup(' '.join(excel[excel.Etiquetas==n].Treinamento)).split() #y é uma lista com todas as palavras de cada categoria
    texto_limpo = [word for word in texto_completo if word not in stopwords]
    f_rel = pd.Series(texto_limpo).value_counts(True)
    f_abs = pd.Series(texto_limpo).value_counts()
    prob = len(texto_limpo)/len(texto_limpo)
    return texto_limpo,f_rel,f_abs,prob

# %% [markdown]
# ### Definindo a probabilidade de cada uma das categorias

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
t3 = pd.Series(excel.Etiquetas).value_counts(True).sort_index()
t3.plot(kind='bar')
plt.title('F.rel por categoria base de Treinamento')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')


plt.subplot(1, 2, 2)
t4 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
t4.plot(kind='bar')
plt.title('F.rel por categoria base de Teste')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')

plt.show()

# %%
ct1 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
ct1.plot(kind='bar')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')
plt.show()
ct1.to_frame()
# Out:
#    Etiquetas
# D   0.275168
# F   0.724832

# %% [markdown]
# Aqui, ainda utilizando a funcao anterior que além de limpar a base, retorna as frequencias de cada uma das categorias, podemos definir as seguintes probabilidades:

# %%
d, rel_d, abs_d, prob_d = Frequencia('D')
f, rel_f, abs_f, prob_f = Frequencia('F')

#Definindo as probabilidades: soma = 1
prob_f = len(f)/len(d + f)
rel_d.head(15)
# Out:
# joker         0.083506
# filme         0.014953
# pra           0.012192
# fav           0.008972
# coringa       0.006441
# assistir      0.005291
# ver           0.005291
# 1             0.005061
# melhor        0.005061
# vou           0.004601
# 2             0.004141
# the           0.004141
# quarentena    0.003911
# fazer         0.003681
# vai           0.003451
# dtype: float64

# %%
print('Número de palavras diferentes na base de treinamento inteira:', len(rel_d+rel_f))
# Out:
# Número de palavras diferentes na base de treinamento inteira: 4735

# %%
def calcula_prob(n):
    alpha = 1
    y,f_rel,f_abs,prob = Frequencia(n)
    probTweetDadoN = []
    probNDadoTweet = []
    for t in excel_teste.Treinamento: #teste aq pq vou classificar pra depois comparar
        PTweetDadoN = 1 #para funcionar o loop que vai multiplicar todas as prob de cada palavra dado a cat
        tweet = cleanup(t).split()
        tweet_limpo = [word for word in tweet if word not in stopwords]
        num_pal_tot_cat = sum(f_abs)#numero de palavras total na categoria n 
        num_pal_pos = len(rel_d+rel_f) #numero de palavras possiveis na base de treinamento inteira
        for p in tweet_limpo:
            if p in f_rel:
                f_abs_cat = f_abs[p] # quantas vezes a palavra aparece no treino
            else: # se a palavra nao tiver na base de treino freq abs é igual a zero
                f_abs_cat = 0
            PPalavraDadoN = (alpha+f_abs_cat)/(num_pal_pos+num_pal_tot_cat) #probabilidade da palavra dado a categoria #elevei a 2 para as probabilidades nao ficarem mt pequenas
            PTweetDadoN = PTweetDadoN * PPalavraDadoN
        PNDadoTweet = prob*PTweetDadoN
        probTweetDadoN.append(PTweetDadoN) #add a probabilidade de cada tweet dado determinada categoria. 
        probNDadoTweet.append(PNDadoTweet)#Como estamos analisando uma mesma coluna, o len da lista de ambas as categorias vai ser igual, é tranquilo fazer uma lista
    return probTweetDadoN, probNDadoTweet

# %%
probTweetDadoD, probDDadoTweet= calcula_prob('D')
probTweetDadoF, probFDadoTweet = calcula_prob('F')
probTweetDadoF,probTweetDadoD
# Out:
# ([3.08353466651132e-58,
#   9.672686018619838e-83,
#   1.872697556517467e-28,
#   3.42076730339565e-83,
#   5.3005819162835913e-48,
#   3.0898653106577495e-13,
#   2.0127643749002947e-15,
#   2.3486278389495032e-24,
#   2.427840108225623e-51,
#   8.807354396060638e-25,
#   3.882500862263789e-34,
#   5.154044687893157e-34,
#   4.574595876828248e-36,
#   1.6772288838039817e-93,
#   6.400590086406561e-44,
#   4.245778510007214e-17,
#   2.5336895547393548e-12,
#   1.4142195789950736e-34,
#   1.0033679414210346e-75,
#   3.024386203093526e-77,
#   3.263942229568045e-16,
#   1.5449326553288748e-14,
#   2.2468539659283583e-23,
#   1.0508686143470574e-53,
#   1.367371127836401e-20,
#   1.0393481832153776e-32,
#   2.635583742322814e-26,
#   1.5186666528765863e-34,
#   2.780878779591974e-13,
#   3.636905379764608e-32,
#   2.4293627037893385e-19,
#   5.489515052193896e-34,
#   1.0118546345989365e-19,
#   3.8328927925432113e-41,
#   6.15507992457327e-105,
#   1.5999071667507713e-124,
#   5.519365621262222e-39,
#   2.0077791784143916e-77,
#   1.4379865381941496e-20,
#   5.453893118877912e-65,
#   1.3268057843772544e-18,
#   5.769545993380564e-46,
#   8.30460105051029e-40,
#   2.6965868908033314e-40,
#   2.1048509134773648e-52,
#   7.164751235637173e-16,
#   9.343702706882074e-21,
#   2.653611568754509e-18,
#   6.284420074765385e-59,
#   5.439903715946743e-17,
#   3.5297996548966254e-28,
#   3.8005343321090315e-12,
#   2.5184874174109186e-09,
#   8.896233341616447e-50,
#   3.994147698482126e-100,
#   2.8870782867093832e-33,
#   1.8231615037818682e-21,
#   2.3558141850149295e-49,
#   7.893848746268977e-54,
#   3.813472802394325e-37,
#   1.7092139097955008e-21,
#   1.1548313146837534e-33,
#   1.3268057843772544e-18,
#   1.1345784605024869e-27,
#   4.465328678802742e-22,
#   4.031535462985502e-27,
#   2.2003806167543863e-33,
#   1.4389662890706044e-101,
#   2.9357847986868796e-26,
#   1.6717752883153402e-15,
#   5.890249651004049e-29,
#   7.915535661650162e-48,
#   3.757804542319205e-23,
#   3.697885352748846e-29,
#   9.115807518909338e-21,
#   2.0817206836589325e-53,
#   6.930833743782379e-111,
#   4.9173985246618905e-79,
#   1.1338597473714474e-53,
#   9.382727212285868e-35,
#   4.318752442302209e-42,
#   5.336048564016584e-26,
#   2.276798725991368e-15,
#   1.0451952154793171e-119,
#   1.079351750318965e-09,
#   1.592166941252705e-16,
#   1.676251781272231e-38,
#   1.2050474711565222e-12,
#   1.3904393897959873e-13,
#   1.5449326553288748e-14,
#   9.785949328956263e-26,
#   2.7161796508312095e-40,
#   7.691462594079753e-19,
#   1.9571898657912528e-26,
#   5.886532705335704e-19,
#   1.592166941252705e-17,
#   4.141631595078707e-27,
#   1.5853237912909147e-23,
#   4.37496295254793e-28,
#   1.481074964762744e-87,
#   1.8414482378079845e-59,
#   1.9054716692281925e-32,
#   2.8888122419078887e-22,
#   2.3257993465152197e-36,
#   2.808567457410448e-24,
#   5.439903715946743e-16,
#   1.6717752883153401e-16,
#   1.9704309306791537e-32,
#   1.8334003857665028e-38,
#   1.0027755013044936e-58,
#   3.0898653106577496e-14,
#   2.4845732316736806e-112,
#   8.82692629471855e-24,
#   9.297959099244405e-36,
#   5.707042814402362e-49,
#   3.007737901345339e-16,
#   4.6972556778990055e-25,
#   3.457140726268669e-47,
#   1.631942362101061e-96,
#   3.8005343321090315e-12,
#   1.079351750318965e-08,
#   1.9164463962716055e-38,
#   4.944617478073733e-71,
#   3.0930409782636854e-51,
#   3.796628714804019e-71,
#   4.5383138420099474e-29,
#   1.7852081470549264e-34,
#   1.020970442117846e-19,
#   1.1548313146837532e-33,
#   2.0813831798505587e-65,
#   2.0510566917546008e-20,
#   1.1295116381093117e-29,
#   1.609082723214892e-63,
#   2.3001996120740306e-93,
#   6.351804533509293e-70,
#   5.302985397027795e-30,
#   5.866236682631288e-55,
#   4.028182361369344e-14,
#   2.357229067414074e-39,
#   3.8870910093924416e-97,
#   1.5965774603470808e-86,
#   1.3823300897890256e-52,
#   1.9235262000996427e-22,
#   1.8687405413764147e-20,
#   3.409062040946439e-30,
#   6.87266907454802e-27,
#   1.6910120440436422e-23,
#   3.053216190634354e-24,
#   3.6638725434910314e-68,
#   7.828759463165011e-25,
#   3.160062762660154e-42,
#   1.0745258112914383e-19,
#   8.70282749378408e-66,
#   7.474962165505659e-20,
#   6.872853963074178e-16,
#   2.3882504118790576e-15,
#   1.640845353403681e-20,
#   9.865604290328229e-61,
#   2.3129616135333787e-76,
#   4.012239224872069e-25,
#   4.111379555348426e-58,
#   4.3390475796473905e-38,
#   2.611153783654436e-15,
#   5.2844126376363825e-24,
#   1.431111931654648e-79,
#   5.2491887981128735e-62,
#   3.8726944785151554e-25,
#   1.8397885404207409e-37,
#   7.059599309793251e-27,
#   2.9933227676602885e-29,
#   6.185713133505768e-44,
#   7.3755702938462615e-09,
#   6.755763190899956e-32,
#   1.8515992749961834e-43,
#   1.2102940697480632e-84,
#   6.069643901669903e-106,
#   2.0510566917546008e-21,
#   2.0510566917546008e-20,
#   3.098155582812124e-26,
#   1.7073650586072976e-67,
#   1.1107961803897317e-34,
#   9.238650517470027e-33,
#   1.75390005917595e-30,
#   6.356703045165529e-63,
#   1.132998890886141e-58,
#   1.798919583864942e-10,
#   2.1306637755915246e-31,
#   7.989950927733784e-49,
#   1.5331571170172845e-40,
#   3.0898653106577496e-14,
#   1.0834694654244604e-103,
#   3.445756805970516e-28,
#   3.0898653106577496e-14,
#   2.1032008248648222e-37,
#   8.113127323230887e-08,
#   2.388250411879058e-16,
#   2.195623037042485e-30,
#   8.928870145589997e-60,
#   4.173314217231952e-77,
#   4.3258114349208496e-13,
#   1.9106003295032459e-16,
#   3.0898653106577496e-14,
#   3.967129215677613e-37,
#   8.747519920569138e-34,
#   9.94018295630601e-76,
#   2.734742255672801e-20,
#   3.0898653106577496e-14,
#   1.9342937054148957e-95,
#   9.6942629673516e-52,
#   3.6133522059140993e-96,
#   3.5989603685851746e-41,
#   7.680708103687875e-43,
#   7.195678335459767e-10,
#   9.95304071704654e-28,
#   1.0723471452439355e-117,
#   2.4718922485261997e-13,
#   1.6629570931446045e-29,
#   1.4885669401792626e-26,
#   1.1246751151828673e-43,
#   1.7248475196904302e-16,
#   2.0946619634523383e-06,
#   5.595635258788322e-60,
#   1.2668447773696774e-12,
#   1.5565916070127086e-75,
#   3.564918637362047e-110,
#   9.244843589102845e-25,
#   1.9227951436638327e-70,
#   1.9896339311597107e-62,
#   2.243419851913563e-97,
#   1.413936563969089e-69,
#   2.2941219265783645e-110,
#   5.094487086672292e-81,
#   6.039698587022176e-56,
#   3.555164932374641e-20,
#   1.7812759394037865e-49,
#   3.8227438947099305e-95,
#   4.3347085320677427e-35,
#   5.3149446723265854e-39,
#   2.0946619634523383e-06,
#   6.928987888102519e-33,
#   4.593040198348765e-62,
#   1.0718603717738795e-39,
#   3.902099082787779e-96,
#   3.0019668996808235e-45,
#   7.435391932483765e-32,
#   7.3755702938462615e-09,
#   1.5449326553288747e-13,
#   5.439903715946743e-17,
#   6.571992198311249e-49,
#   4.1913893883836715e-54,
#   1.9002671660545158e-12,
#   2.335925676720518e-20,
#   9.571597894854806e-19,
#   7.2579603967657015e-59,
#   2.712764367149738e-60,
#   1.5289565865561677e-48,
#   1.9002671660545158e-12,
#   2.6983793757974126e-09,
#   3.85069274045092e-108,
#   1.8127872808084647e-51,
#   8.928870145589996e-60,
#   2.575336250480545e-47,
#   9.11580751890934e-21,
#   5.597563016162982e-24,
#   1.3433408972349443e-26,
#   7.973832889939011e-46,
#   5.004136258795509e-55,
#   6.283985890357014e-06,
#   1.437334797203704e-41,
#   1.3268057843772544e-17,
#   3.0898653106577496e-14,
#   2.2100223484031606e-128,
#   2.4612680301055214e-19,
#   3.0898653106577496e-14,
#   6.334223886848387e-13,
#   1.8864317640913083e-49,
#   2.6333856355501277e-41,
#   1.4347509511396455e-108,
#   3.8115015325793497e-88,
#   1.4271428889449299e-55,
#   2.3817071042868197e-25,
#   5.4382278391350745e-95,
#   2.513235516767395e-14,
#   1.0879807431893486e-16,
#   1.536141620737575e-43,
#   3.314365873142372e-31,
#   1.3904393897959873e-13,
#   5.127641729386503e-20,
#   2.853067576435615e-217,
#   1.8789022711596022e-24,
#   1.3268057843772543e-16,
#   1.834330087402579e-49,
#   5.978091154618823e-56,
#   2.560236034562625e-45,
#   4.791826978133297e-58,
#   1.6738720441165392e-62,
#   1.5220699573371783e-58,
#   1.8465752721793208e-30],
#  [4.5853596708976964e-49,
#   5.3807430480003304e-77,
#   8.31264317582445e-32,
#   2.592287654475313e-84,
#   9.292067730333267e-44,
#   4.2802129867186835e-13,
#   3.3806627298945647e-15,
#   8.227793433384141e-23,
#   1.798045236698757e-46,
#   5.570901803853844e-24,
#   2.4295278676787365e-39,
#   1.1418465900857764e-33,
#   2.3788470626787006e-36,
#   3.8498348881228485e-88,
#   1.9974096834766091e-41,
#   1.001481237258005e-16,
#   1.334920822300106e-12,
#   1.239452136158953e-34,
#   1.5748147500937524e-81,
#   1.0858662664846444e-77,
#   1.4698533608237238e-16,
#   5.3502662333983544e-14,
#   4.989638085069096e-23,
#   1.244312429330502e-53,
#   1.692984202263944e-18,
#   1.8703447145605014e-31,
#   1.0191882418583083e-25,
#   5.148493488660266e-34,
#   1.1235559090136544e-12,
#   7.422002835557546e-33,
#   2.5894796050627152e-19,
#   1.9030776501429605e-35,
#   7.005451871437009e-18,
#   1.0497959922068614e-41,
#   7.064193279426276e-105,
#   8.027260085033561e-122,
#   1.0204017044250694e-36,
#   9.122941744328308e-74,
#   3.849149379910444e-22,
#   1.0075870264696029e-58,
#   2.356426440607071e-17,
#   6.66870220177821e-46,
#   1.1085845677704456e-38,
#   4.893653724517692e-41,
#   1.3304188494401723e-48,
#   2.0500910033281517e-15,
#   1.618424753164197e-20,
#   3.534639660910606e-17,
#   4.8004960518133874e-58,
#   1.4698533608237238e-16,
#   1.4469956520210553e-26,
#   9.344445756100742e-12,
#   3.207013783493774e-08,
#   1.0665535108547157e-53,
#   1.175211264195555e-99,
#   5.195401984890283e-32,
#   6.486529510589824e-22,
#   3.690964883021926e-47,
#   7.406621603157748e-56,
#   1.7821708229977843e-36,
#   3.113534165083115e-20,
#   1.5586205954670847e-31,
#   1.0603918982731818e-16,
#   9.30323834967885e-27,
#   2.6843176076415754e-21,
#   1.9621378570913797e-27,
#   9.515388250714804e-34,
#   3.5416104260614573e-106,
#   7.142181799812621e-26,
#   4.948495525274848e-16,
#   6.660771775500363e-34,
#   1.2027454532605931e-46,
#   6.170845075038104e-23,
#   1.761559924199546e-27,
#   5.708145969319044e-20,
#   1.5553905366631274e-54,
#   1.953187485433585e-109,
#   1.5465450621970263e-86,
#   4.3493554057004636e-55,
#   2.336084488152631e-39,
#   1.615070757241325e-42,
#   1.446995652021055e-27,
#   4.7128528812141416e-17,
#   1.3433814556104899e-114,
#   5.8309341518068626e-08,
#   7.65838593197298e-17,
#   1.0372422779352186e-36,
#   1.9260958440234077e-12,
#   5.3502662333983544e-14,
#   5.3502662333983544e-14,
#   5.713745439850097e-25,
#   5.080915963259589e-46,
#   4.063162085433465e-18,
#   1.4284363599625243e-25,
#   1.3594767926579255e-18,
#   3.8291929659864905e-16,
#   4.9826980713072865e-26,
#   7.713556343797631e-24,
#   4.433282187570481e-28,
#   6.151997808623286e-95,
#   2.7826518433763206e-59,
#   1.9049807277931033e-32,
#   8.910068009051955e-24,
#   3.3267188695958645e-35,
#   7.128054407241564e-24,
#   2.9397067216474476e-16,
#   1.5552414508006667e-15,
#   7.182123703912327e-29,
#   1.676351156258939e-38,
#   3.425215892233269e-58,
#   5.3502662333983544e-14,
#   4.525398387358136e-105,
#   2.138416322172469e-23,
#   6.864657984880355e-36,
#   9.091046509906222e-49,
#   9.710548518985183e-19,
#   3.7710719903010635e-23,
#   9.516227762061836e-46,
#   8.318234862964553e-104,
#   5.339683289200424e-12,
#   2.0408269531324018e-08,
#   7.1648576468118294e-37,
#   8.47747404041222e-84,
#   2.3786221473842144e-60,
#   6.941464255957243e-76,
#   5.50487476312358e-28,
#   7.56485309933815e-33,
#   1.4010903742874014e-19,
#   3.4636013232601875e-33,
#   5.437330298005571e-70,
#   2.2067173395026573e-18,
#   1.1637700446154232e-29,
#   3.9549013603812276e-66,
#   8.045631950099997e-91,
#   2.4832007836861827e-66,
#   3.0851495925198084e-29,
#   1.0957657092499054e-52,
#   2.650979745682955e-16,
#   1.3201265355539144e-37,
#   1.4617146793288922e-92,
#   3.02766930014722e-85,
#   1.638553603330378e-52,
#   3.8804330780197955e-20,
#   4.855274259492592e-19,
#   2.7221908169292433e-30,
#   1.9055335718504701e-28,
#   2.674032865849845e-22,
#   5.713745439850097e-24,
#   7.783009675630086e-73,
#   1.714123631955029e-24,
#   8.447378453036493e-41,
#   1.2947398025313578e-18,
#   2.1638355267573188e-70,
#   1.9421097037970366e-19,
#   1.2724702779278181e-15,
#   8.483135186185453e-16,
#   1.0378447216943716e-20,
#   1.4966005897909296e-63,
#   1.3268811937028608e-72,
#   5.346040805431173e-24,
#   2.289134424052875e-58,
#   7.322301850539046e-35,
#   4.409560082471171e-16,
#   1.1427490879700195e-23,
#   1.3526623740625445e-86,
#   1.551675491495236e-60,
#   2.7681655951707144e-26,
#   1.0497959922068613e-41,
#   4.378734668724584e-26,
#   6.955344407271868e-28,
#   6.229558635073683e-42,
#   1.2123750908129562e-08,
#   1.2568716481846568e-28,
#   2.9128891217367217e-42,
#   2.983956904570054e-90,
#   5.477290231908514e-97,
#   1.3621711972238627e-20,
#   8.173027183343176e-20,
#   5.662156899212825e-28,
#   7.746422444733536e-64,
#   2.0021919122567707e-34,
#   1.2468964763736678e-30,
#   4.580266389879273e-29,
#   7.0545476809266535e-68,
#   8.880926576781339e-64,
#   9.71822358634477e-10,
#   8.641875609299183e-32,
#   4.99946958213148e-53,
#   3.628094949066912e-38,
#   1.0700532466796709e-13,
#   3.4918329498587455e-99,
#   4.7091308570193114e-27,
#   6.420319480078025e-12,
#   3.418186214282887e-43,
#   6.061875454064782e-08,
#   7.051606123516659e-15,
#   5.084999692711362e-29,
#   5.129149541331475e-59,
#   5.443804074398158e-81,
#   7.062351428085828e-12,
#   9.425705762428284e-17,
#   1.6050798700195065e-13,
#   1.4301370801834075e-34,
#   1.5223065547270676e-31,
#   1.9784550404132088e-75,
#   9.340602495249345e-20,
#   5.3502662333983544e-14,
#   5.375841931295712e-90,
#   2.0697519199962668e-52,
#   2.5636226683614423e-90,
#   5.606602771566315e-41,
#   1.946275995579608e-37,
#   2.429555896586193e-09,
#   5.599935394825871e-29,
#   1.7883411675686364e-118,
#   3.2101597400390125e-13,
#   1.2219585468461945e-28,
#   1.1301914056846347e-25,
#   5.768109847290447e-44,
#   4.2415675930927276e-14,
#   4.41304533055916e-06,
#   6.72138126419401e-62,
#   4.004762466900318e-12,
#   2.6107319552221565e-78,
#   6.5699439787806745e-105,
#   2.624969716324627e-29,
#   1.7124371056958845e-74,
#   6.796063278240611e-61,
#   1.563192911242005e-100,
#   1.8771735552638288e-67,
#   2.4818640189605434e-103,
#   3.027094042980193e-79,
#   6.061232388653266e-61,
#   1.6605515547109946e-19,
#   6.820867452347697e-49,
#   5.531371965693749e-89,
#   3.8613701164951993e-35,
#   4.199183968827445e-41,
#   1.3239135991677481e-05,
#   2.77088105860815e-32,
#   1.6183400681668826e-58,
#   3.3639616629397878e-40,
#   6.644157633313149e-93,
#   4.3213190267522784e-44,
#   2.6695892163423604e-36,
#   1.2123750908129562e-08,
#   4.815239610058518e-13,
#   1.4698533608237238e-16,
#   2.0956238189962203e-49,
#   1.717686323071803e-60,
#   1.8688891512201485e-11,
#   4.855274259492591e-20,
#   1.8162282629651504e-20,
#   2.9036367061318123e-58,
#   6.407062063820264e-57,
#   7.049057601527285e-49,
#   1.334920822300106e-12,
#   1.943644717268954e-09,
#   9.135786477728674e-121,
#   1.2624658811209228e-47,
#   5.129149541331475e-59,
#   1.6112131660633797e-48,
#   1.945958853176947e-21,
#   8.570618159775147e-24,
#   2.0383764837166168e-25,
#   3.991664417135656e-51,
#   1.7918098982359226e-51,
#   2.2065226652795805e-05,
#   2.0995919844137228e-41,
#   5.3019594913659083e-17,
#   2.1401064933593417e-13,
#   3.4800776845936038e-121,
#   2.0756894433887433e-20,
#   1.0700532466796709e-13,
#   1.334920822300106e-12,
#   2.542690233715414e-48,
#   1.005640292028154e-42,
#   1.7742564143170103e-110,
#   6.999538213478665e-84,
#   2.2809629724979975e-57,
#   2.511536457076966e-26,
#   2.3780634098856725e-91,
#   7.349266804118619e-16,
#   1.4698533608237238e-16,
#   2.524503905505159e-40,
#   2.138864213301548e-30,
#   5.3502662333983544e-14,
#   1.2973059021179647e-19,
#   3.022136932116485e-215,
#   1.8512535225114317e-21,
#   2.474247762637424e-16,
#   1.2640270654262914e-51,
#   1.1975055605614485e-57,
#   1.3842049106492896e-39,
#   1.8464938348793306e-57,
#   1.8995315178115644e-63,
#   2.3786221473842144e-60,
#   1.224985867618159e-29])

# %% [markdown]
# tenho uma lista com a probabilidade de cada tweet pra cada categoria, logo probDDadoTweet[i] é correspondente a probFDadoTweet[i]

# %%
class_tweet = []
for i in range(len(excel_teste)):
    if probDDadoTweet[i]>probFDadoTweet[i]:
        class_tweet.append('D')
    else:
        class_tweet.append('F')


excel_teste['class_auto'] = class_tweet
excel_teste.head()
# Out:
#                                          Treinamento Etiquetas class_auto
# 0  rt @_dcbrasil: maior ato do cinema de 2019! \n...         D          D
# 1  eu ñ fui assistir joker no cinema aqui pq so t...         D          D
# 2  @dracoh8 @caiquecerq @mateuscrz098 @joker_bsa ...         F          F
# 3  @joker_bsa @mitofaztd @portalprior mas o prior...         F          F
# 4  rt @itzguk: kpopper atacando o bts por tudo e ...         F          D

# %% [markdown]
# ### ETAPA 6 - Verificando a performance do classificador
#
#
# Nesta etapa, iremos verificar a acurácia do nosso classificador. No gráfico a seguir é possível observar como se comporta a classificacao do nosso classificador

# %%
ct1 = pd.Series(excel_teste.class_auto).value_counts(True).sort_index()
ct1.plot(kind='bar')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')
plt.show()
ct1.to_frame()
# Out:
#    class_auto
# D    0.651007
# F    0.348993

# %% [markdown]
#  Uma classificacao correta quer dizer que a categoria definida manualmente é igual a categoria definida pelo nosso classificador. Sendo assim, ao fazer um cruzamento das variáveis etiquetas e class_auto, obtemos a seguinte tabela:

# %%
ct = pd.crosstab(excel_teste.Etiquetas, excel_teste.class_auto)
ct
# Out:
# class_auto    D    F
# Etiquetas
# D            79    3
# F           115  101

# %% [markdown]
# Fazendo uma análise dela, é possivel calcular o numero de acertos e erros do classificador. Sendo que
# - quando class_auto = Etiquetas - significa que ele acertou
# - quando class_auto diferente de Etiquetas - significa que ele errou
#
#
# Logo:

# %%
acertos = ct.D['D'] + ct.F['F']
erros = ct.D['F'] + ct.F['D']
erros, acertos
# Out:
# (118, 180)

# %%
acuracia = acertos*100/(erros+acertos)
print('Acurácia do classificador: {0}%'.format(acuracia.round(3)))
# Out:
# Acurácia do classificador: 60.403%

# %% [markdown]
# ## CONCLUSÃO

# %% [markdown]
# - Faça um comparativo qualitativo sobre os percentuais obtidos para que possa discutir a performance do seu classificador.
# - Explique como são tratadas as mensagens com dupla negação e sarcasmo.
# - Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?
#
#
# Opcionalmente:
#
# - Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
#
# *Ao se utilizar o próprio classificador para gerar mais amostras de treinamento, o classificador acaba ficando
# 'viciado', ou seja, acaba-se por prejudicar os resultados obtidos, e eles acabam não tendo uma qualidade boa.
# Seria o contrário de puxar mais tweets, que melhora a qualidade dos dados e dos resultados, por ter um espaço
# amostral muito maior.*
#
#
#
# - Propor diferentes cenários de uso para o classificador Naive-Bayes. Pense em outros cenários sem intersecção com este projeto.
# - Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer. Indique material de pesquisa sobre o assunto).

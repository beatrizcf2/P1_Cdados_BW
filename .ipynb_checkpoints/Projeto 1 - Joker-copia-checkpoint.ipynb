# %% [markdown]
# # PROJETO 1 - CLASSIFICADOR DE SENTIMENTO DO FILME JOKER
# __________________________________________________________________________________________________________________
#
# ### Alunos:
#
# Nome: Beatriz Cabral Fernandes
#
# Nome: Eduardo Ancona Mateus

# %% [markdown]
# ## 1. INTRODUÇÃO
#
# A proposta desse projeto é desenvolver um classificador que irá analisar como o público está reagindo ao premiado filme ***Joker***, do diretor *Todd Phillips*. Para isso, será utilizado como método o famoso algoritmo de Naive-Bayes.

# %% [markdown]
# ## 2. DESENVOLVIMENTO E METODOLOGIA
#
# A fim de simplificar a explicação do processo de desenvolvimento do projeto, ele será dividido em 6 etapas
#
# ### ETAPA 1 - Preparando o ambiente no Jupyter
#
# Nessa etapa, serão baixadas e importadas todas as bibliotecas relevantes para o código, bem como implementadas todas as funções a serem utilizadas

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

#Importando as bibliotecas
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle
from IPython.display import Image
import re
import matplotlib.pyplot as plt 
import numpy as np


#criando funcao de limpeza de caracteres
def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    #import string
    punctuation = '[! - . : ? ; / _ # ) ( , \ $ " = } { [ ] ]' # Note que os sinais [] são delimitadores de um conjunto.
    links = re.sub(r'http\S+','',text)
    mentions = re.sub('@[A-Za-z0-9]+','',links)
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, ' ', mentions)
    return text_subbed

# %% [markdown]
# ### ETAPA 2 - Autenticando no Twitter
#
# Conta: `@datascience_dudle`
#
#
# Nessa etapa será feita a autenticação no twitter, e posteriormente a coleta de tweets a partir de uma palavra chave. O código pode ser observado no arquivo [Projeto1_Obtenção_dos_tweets.ipynb](http://localhost:8888/notebooks/2%20Semestre%20-%20DP/CDADOS/P1_Cdados_BW/Projeto1_Obten%C3%A7%C3%A3o_dos_tweets.ipynb)

# %% [markdown]
# ____________
#
# ### ETAPA 3 - Escolha de um produto e coleta das mensagens
#
# No arquivo `Projeto1_Obtenção_dos_tweets.ipynb` foram coletados tweets relacionados ao filme ***Joker*** e salvos em na planilha do excel `Joker.xlsx`. Ao coletar os tweets com essa keyword, obtivemos 901 tweets para treinamento e 300 para teste. A seguir foi feita a leitura dos arquivos.

# %%
# Fazendo a leitura da planilha de treinamento
excel = pd.read_excel('Joker.xlsx', sheet_name='Treinamento')
excel_teste = pd.read_excel('Joker.xlsx', sheet_name='Teste')
#excel_teste.rename(columns={'Etiquetas':'Class_manual'}, inplace=True)

# %%
excel_teste.head()
# Out:
#                                          Treinamento  Etiquetas
# 0  rt @_dcbrasil: maior ato do cinema de 2019! \n...          1
# 1  eu ñ fui assistir joker no cinema aqui pq so t...          3
# 2  @dracoh8 @caiquecerq @mateuscrz098 @joker_bsa ...          5
# 3  @joker_bsa @mitofaztd @portalprior mas o prior...          5
# 4  rt @itzguk: kpopper atacando o bts por tudo e ...          5

# %% [markdown]
# ### ETAPA 4 - Classificação manual dos tweets
#
# Vale ressaltar que o foco desse estudo é analisar o sentimento dos tweets relacionados ao premiado filme ***Joker***.
# Desta forma, foram previamente estabelecidas 5 categorias para a classificação das mensagens:
#
# * `P` - ***Crítica positiva*** – se a mensagem transmitida é uma crítica positiva;
# * `N` - ***Crítica negativa*** – se a mensagem transmitida é uma crítica negativa;
# * `I` - ***Irrelevante*** – se a mensagem transmitida estiver no contexto proposto, mas não for relevante para análise;
# * `R` - ***Reação*** - se a mensagem transmitida trata-se de uma reação ou emoção em relação ao filme ou a uma cena;
# * `F` - ***Fora do contexto*** - se a mensagem transmitida esta fora do contexto proposto.
#
#
# Estabelecidas as categorias e selecionados os tweets, foi utilizada a base de treinamento, na qual as mensagens foram qualificadas manualmente no excel de acordo com a categoria mais adequada. Conforme mostra a tabela a seguir:

# %%
excel.loc[:,'Etiquetas'] = excel['Etiquetas'].astype('category')
excel.Etiquetas.cat.categories = ['P','N','I','R','F']
excel.head()
# Out:
#                                          Treinamento Etiquetas
# 0  mortos pelo regime genocida da china 100.000.0...         F
# 1  @thiago_joker tempos de quarentena, sei lá né ...         F
# 2  se o governador do rio de janeiro candidatar p...         F
# 3  @jillajeeva332 @yutheesh0011 @joker_rowdy @pok...         F
# 4  galera só pra relembrar os filmes da dc de mai...         I

# %%
#Grafico para observar a distribuição das categorias P,N,I,R,F

fig = plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
t1 = pd.Series(excel.Etiquetas).value_counts(True).sort_index()
t1.plot(kind='bar')
plt.title('F.rel por categoria base de Treinamento')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')


plt.subplot(1, 2, 2)
t2 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
t2.plot(kind='bar')
plt.title('F.rel por categoria base de Teste')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')

plt.show()

# %% [markdown]
# Acima, observa-se um número de tweets da categoria F muito grande em detrimento do resto das categorias. Por conta disso, vamos primeiro classificar os tweets em 2 principais categorias: como *Dentro do contexto (soma das categorias P,N,R e I)* ou *Fora do contexto (categoria F)*, a fim de minimizar o enviesamento do classificador.

# %%
excel = excel.apply(pd.Series.replace, to_replace=['P','N','I', 'R'] , value='D')
excel.head()
# Out:
#                                          Treinamento Etiquetas
# 0  mortos pelo regime genocida da china 100.000.0...         F
# 1  @thiago_joker tempos de quarentena, sei lá né ...         F
# 2  se o governador do rio de janeiro candidatar p...         F
# 3  @jillajeeva332 @yutheesh0011 @joker_rowdy @pok...         F
# 4  galera só pra relembrar os filmes da dc de mai...         D

# %%
excel_teste.loc[:,'Etiquetas'] = excel_teste['Etiquetas'].astype('category')
excel_teste.Etiquetas.cat.categories = ['P','N','I','R','F']
excel_teste = excel_teste.apply(pd.Series.replace, to_replace=['P','N','I', 'R'] , value='D')
excel_teste.head()
# Out:
#                                          Treinamento Etiquetas
# 0  rt @_dcbrasil: maior ato do cinema de 2019! \n...         D
# 1  eu ñ fui assistir joker no cinema aqui pq so t...         D
# 2  @dracoh8 @caiquecerq @mateuscrz098 @joker_bsa ...         F
# 3  @joker_bsa @mitofaztd @portalprior mas o prior...         F
# 4  rt @itzguk: kpopper atacando o bts por tudo e ...         F

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
t3 = pd.Series(excel.Etiquetas).value_counts(True).sort_index()
t3.plot(kind='bar')
plt.title('F.rel por categoria base de Treinamento')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')


plt.subplot(1, 2, 2)
t4 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
t4.plot(kind='bar')
plt.title('F.rel por categoria base de Teste')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')

plt.show()

# %% [markdown]
# ### ETAPA 5 - Montando o Classificador Naive-Bayes

# %% [markdown]
# ### Breve explicação de *Naive Bayes*
# O algoritmo de *Naive Bayes* é um classificador probabilístico baseado no teorema de Bayes, utilizado no processo de machine learning. O algoritmo supõe que uma característica independe da outra para acontecer, ou seja, mesmo na presença de uma característica particular em uma classe, isso não afeta na probabilidade de qualquer característica ocorrer. O teorema de bayes é escrito da seguinte forma:

# %% [markdown]
# ![title](img/bayes.png)

# %% [markdown]
# * $P(A)$ - Probabilidade a priori
# * $P(B)$ - Probilidade Total
# * $P(A|B)$ - posteriori
# * $P(B|A)$ - verossimilhanca
#
#
# Esse método será utilizado no projeto, uma vez que permite calcular a probabilidade de uma mensagem receber diferentes classificações, por exemplo, dado um tweet, assumindo que as palavras nele não tem nenhuma relação entre si.
#
# A partir do nosso modelo, poderíamos reescrever o teorema de bayes da seguinte forma:

# %% [markdown]
# # $P(C|P) = \frac{P(P|C).P(C)}{P(P)}$

# %% [markdown]
# A variável C é a classe variável que representa a categoria de um tweet, a partir das condições estabelecidas (probabilidade de ocorrência de uma palavra dada as condições). A variável P representa as palavras ocorridas nos tweets.
#
#
# P pode ser:

# %% [markdown]
# ![title](img/bayes2.png)

# %% [markdown]
# Substituindo P por cada uma das possíveis palavras, temos:

# %% [markdown]
# ![title](img/bayes3.png)

# %% [markdown]
# Nesse momento queremos classificar se um tweet está dentro ou fora do contexto do filme Joker. Para tanto é necessário analisar analisar as probabilidades.
#
#
# Ou seja, precisa decidir se:
#
# ## $P(Dentro do contexto|frase) > P(Fora do contexto|frase)$
#
#
#
# Utilizando o teorema de Bayes, temos:
#
# ## $P(D|frase) = \frac{P(frase|D)P(D)}{P(frase)}$
#
# e que:
#
# ## $P(F|frase) = \frac{P(frase|F)P(F)}{P(frase)}$
#
#
#
# Para implementar esse algoritmo, uma nova tabela deve ser criada com as palavras e suas respectivas frequências relativas em cada uma das categorias. Porém antes disso, deverá ser feita uma limpeza das mensagens, removendo pontuações e caracteres que não convém a análise.

# %%
# Verificando categorias do meu dataset
list(excel)
# Out:
# ['Treinamento', 'Etiquetas']

# %%
# Juntando todos os tweets da base de treinamento
texto_completo = cleanup(' '.join(excel.Treinamento)).split()
palavras_total = pd.Series(texto_completo).value_counts()
palavras_total
# Out:
# o                           450
# de                          391
# joker                       355
# que                         336
# a                           332
# e                           313
# é                           242
# do                          234
# não                         176
# rt                          146
# eu                          145
# -                           132
# pra                         126
# :                           121
# com                         116
# um                          108
# no                          107
# da                          104
# em                           91
# se                           89
# _joker                       89
# mais                         83
# por                          80
# uma                          76
# mas                          68
# filme                        66
# na                           65
# os                           60
# fav                          59
# tem                          54
#                            ...
# vs.                           1
# elege                         1
# porcaria                      1
# enclaves,                     1
# _thesaint                     1
# agosto?                       1
# contágio,                     1
# paro                          1
# (lula)                        1
# #fantastico                   1
# sentence                      1
# identificam-se                1
# quadrinho                     1
# ficaria:                      1
# economia                      1
# caralho!!!!!!!!!!!!!!!!!      1
# viva                          1
# misfits,                      1
# hélio                         1
# produtivos                    1
# drogada                       1
# posição                       1
# _caoshumano                   1
# mixagem:                      1
# conhecemos                    1
# tirado                        1
# pouco.                        1
# sejam                         1
# internados                    1
# shaw                          1
# Length: 5057, dtype: int64

# %%
texto_completo
# Out:
# ['mortos',
#  'pelo',
#  'regime',
#  'genocida',
#  'da',
#  'china',
#  '100.000.000',
#  'de',
#  'pessoas',
#  'mortos',
#  'pelo',
#  'regime',
#  '"genocida"',
#  'do',
#  'bolsonaro',
#  '0',
#  'vão',
#  'pentear',
#  'macaco...esquerdista',
#  'tem',
#  'retardo',
#  'mental',
#  '_joker',
#  'tempos',
#  'de',
#  'quarentena,',
#  'sei',
#  'lá',
#  'né',
#  'hahahahhahaha',
#  'se',
#  'o',
#  'governador',
#  'do',
#  'rio',
#  'de',
#  'janeiro',
#  'candidatar',
#  'para',
#  'presidente',
#  'eu',
#  'faço',
#  'campanha',
#  'até,',
#  'o',
#  'cara',
#  'foi',
#  'o',
#  'único',
#  'até',
#  'agora',
#  'que',
#  'detonou',
#  'ao',
#  'vivo',
#  'o',
#  '"presidente"',
#  'que',
#  'só',
#  'faz',
#  'política',
#  'nesse',
#  'momento',
#  'e',
#  'não',
#  'resolve',
#  'nada',
#  '_rowdy',
#  '_gvan',
#  '_pokkiri7',
#  'atha',
#  'maranthuta',
#  'namba',
#  'galera',
#  'só',
#  'pra',
#  'relembrar',
#  'os',
#  'filmes',
#  'da',
#  'dc',
#  'de',
#  'maior',
#  'bilheteria',
#  'no',
#  'japão🇯🇵',
#  'onde',
#  'estará',
#  '#birdsofprey',
#  'isso',
#  'só',
#  'o',
#  'tempo',
#  'dirá:',
#  '1-#joker$46.7m',
#  '2-#constantine$24.5m',
#  '3-#thedarkknightrises$24.1m',
#  '4-#batmanvsuperman',
#  '$16.5m',
#  '5-#suicidesquad',
#  '$15.6m',
#  '6-#aquaman',
#  '$14.8m',
#  '7-#thedarkknight',
#  '$14.5m',
#  '(1/2)',
#  '_lem0s',
#  '_peroni',
#  'essa',
#  'foi',
#  'uma',
#  'frase',
#  'bem',
#  'do',
#  'joker',
#  'antes',
#  'de',
#  'matar',
#  'o',
#  'murray',
#  'marques,',
#  'sendo',
#  'realista,',
#  'apesar',
#  'de',
#  'não',
#  'gostar',
#  'desse',
#  'cenário',
#  'vai',
#  'foder',
#  'a',
#  'saúde',
#  'e',
#  'vai',
#  'foder',
#  'a',
#  'economia',
#  '19-',
#  'the',
#  'dark',
#  'knight',
#  '{assiste',
#  'toda',
#  'a',
#  'trilogia}',
#  '(2008)',
#  'sou',
#  'suspeita',
#  'pra',
#  'falar',
#  'pq',
#  'amo',
#  'tudo',
#  'que',
#  'envolve',
#  'o',
#  'universo',
#  'do',
#  'batman,',
#  'mas',
#  'cara',
#  'esse',
#  'é',
#  'o',
#  'melhor',
#  'batman',
#  'e',
#  'o',
#  'melhor',
#  'joker',
#  'trailer',
#  ';',
#  'você',
#  'defende',
#  'quem',
#  'é',
#  'responsável',
#  'por',
#  'disseminar',
#  'o',
#  'mortal',
#  '#viruschines',
#  'que',
#  'infectou',
#  'o',
#  'mundo',
#  'e',
#  'a',
#  'você',
#  'mesmo.',
#  'foda-se!',
#  'dança',
#  'da',
#  'morte',
#  'ele',
#  'não',
#  'falou',
#  'errado,',
#  'ele',
#  'só',
#  'falou',
#  'em',
#  'mineres',
#  'rsrs',
#  'finalmente',
#  'vou',
#  'assistir',
#  'o',
#  'joker',
#  'carai',
#  'joker,',
#  'o',
#  'ícone',
#  'dos',
#  'incels',
#  'nerds',
#  'falando',
#  'a',
#  '"verdade"',
#  'fora',
#  'da',
#  'sua',
#  'matrix.',
#  'isto',
#  'de',
#  'estar',
#  'muito',
#  'tempo',
#  'em',
#  'casa',
#  'não',
#  'me',
#  'esta',
#  'a',
#  'fazer',
#  'bem...hoje',
#  'sonhei',
#  'que',
#  'estava',
#  'a',
#  'fazer',
#  'sexo',
#  'com',
#  'o',
#  'joker',
#  'rt',
#  ':',
#  'filha',
#  'do',
#  'joker',
#  '😂',
#  '_bsa',
#  'sim,',
#  'pra',
#  'saírem.',
#  'babu',
#  'só',
#  'não',
#  'saiu',
#  'na',
#  'anterior',
#  'prq',
#  'foi',
#  'com',
#  'o',
#  'pyong',
#  'e',
#  'nessa',
#  'semana',
#  'qualquer',
#  'um',
#  'que',
#  'for,',
#  'não',
#  'sai,',
#  'prq',
#  'será',
#  'do',
#  'daniel,',
#  'se',
#  'ele',
#  'não',
#  'sair',
#  'no',
#  'bate-e-volta.',
#  'a',
#  'gabi',
#  'vai',
#  'estar',
#  'imune,',
#  'a',
#  'rafa',
#  'vai',
#  'imunizar',
#  'ela',
#  'com',
#  'o',
#  'anjo.',
#  'rt',
#  ':',
#  'saudades...',
#  '😂🤷\u200d♂️',
#  'estava',
#  'assistindo',
#  'ainda',
#  'a',
#  'pouco',
#  'rt',
#  '_mask:',
#  'estou',
#  'deveras',
#  'confuso',
#  'louquíssimo',
#  'os',
#  'capeto',
#  'morrendo',
#  'ces',
#  'perceberam',
#  'que',
#  'no',
#  'joker',
#  '(2019)',
#  'ele',
#  'ta',
#  'sempre',
#  'com',
#  'a',
#  'maquiagem',
#  'do',
#  'olho',
#  'esquerdo',
#  'borrada?',
#  'e',
#  'dizem',
#  'que',
#  'sempre',
#  'que',
#  'o',
#  'choro',
#  'é',
#  'de',
#  'tristeza',
#  'as',
#  'lágrimas',
#  'saem',
#  'primeiro',
#  'do',
#  'olho',
#  'esquerdo?',
#  'to',
#  'em',
#  'shokk',
#  'com',
#  'esse',
#  'filme',
#  'o',
#  'meu',
#  'desejo',
#  'mais',
#  'sincero',
#  'é',
#  'de',
#  'que',
#  'o',
#  'todd',
#  'phillips',
#  'nunca',
#  'tenha',
#  'que',
#  'explicar',
#  'o',
#  'final',
#  'de',
#  'joker',
#  'passo',
#  'os',
#  'personagens',
#  'de',
#  "'batman:",
#  'a',
#  'série',
#  "animada',",
#  'numa',
#  'versão',
#  'em',
#  '3d',
#  'feita',
#  'pelo',
#  'diretor',
#  'de',
#  'arte',
#  'de',
#  "'god",
#  'of',
#  "war',",
#  'raff',
#  'grasseti.',
#  'ficou',
#  'incrível!',
#  '#coringa',
#  '#joker',
#  '#harleyquinn',
#  '#arlequina',
#  '"humm',
#  'esses',
#  'gays',
#  'são',
#  'todos',
#  'pagos',
#  'para',
#  'fingir',
#  'sofrimento',
#  'e',
#  'blá',
#  'blá',
#  'blá',
#  'se',
#  'tivessem',
#  'assistido',
#  'o',
#  'filme',
#  'do',
#  '#joker',
#  'eles',
#  'teria',
#  'entendido',
#  'a',
#  'verdade',
#  'de',
#  'lá',
#  's0ciedade',
#  'mas',
#  'eles',
#  'nunca',
#  'me',
#  'dão',
#  'atenção',
#  '😡😡😡😭😭😭😭😭nunca',
#  'dão',
#  'atenção',
#  'a',
#  'mim',
#  'creverson',
#  'homem',
#  'de',
#  '34',
#  'hetero',
#  'foda"',
#  'nem',
#  'passou',
#  'pela',
#  'minha',
#  'cabeça',
#  'trocar',
#  'de',
#  'foto',
#  'do',
#  'perfil.',
#  'siga',
#  'todos',
#  'que',
#  'fav',
#  'e',
#  'rt',
#  'esse',
#  'tuite.',
#  '#paz',
#  '#bbb20',
#  '#vida',
#  '#futebol',
#  '#brasileirao2020',
#  '#sdv',
#  '#mundial',
#  '#gremio',
#  '#esporte',
#  '#tmj',
#  '#hanking',
#  '#bom',
#  '#aves',
#  '#joker',
#  '#poker',
#  'joker',
#  'é',
#  'uma',
#  'obra',
#  'de',
#  'arte',
#  'mesmo,',
#  'nao',
#  'tem',
#  'jeito',
#  'atenção:',
#  'prior',
#  'incorporou',
#  'o',
#  'joker',
#  'altura',
#  'ー',
#  '1,70',
#  'idade',
#  'ー17',
#  'tamanho',
#  'do',
#  'pé',
#  'ー',
#  '40',
#  'signo',
#  'ー',
#  'touro',
#  'tatuagens',
#  'ー0',
#  'piercings',
#  'ー',
#  '0',
#  'cor',
#  'fav',
#  'ー',
#  'cinza',
#  'filme',
#  'fav',
#  'ー',
#  'joker',
#  'comida',
#  'fav',
#  '—strogonoff',
#  'bebida',
#  'fav',
#  'ー',
#  'coca-cola',
#  'série',
#  'fav',
#  'ー',
#  'supernatural',
#  'time',
#  '-',
#  'sport,',
#  'real',
#  'madrid',
#  'e',
#  'são',
#  'paulo',
#  'genocida',
#  'sabe',
#  'o',
#  'nome',
#  'disse',
#  '?',
#  'indignação',
#  'seletiva.',
#  'mas',
#  'eu',
#  'ñ',
#  'quero',
#  'amizade',
#  'entre',
#  'pscipota',
#  'nível',
#  'joker',
#  'e',
#  'a',
#  'harley',
#  'mas',
#  'tb',
#  'ñ',
#  'quero',
#  'o',
#  'q',
#  'a',
#  'dc',
#  'fez',
#  '_duart7',
#  'vou',
#  'pensar',
#  'no',
#  'de',
#  'amanhã',
#  'ainda',
#  'kkkj',
#  'eu',
#  'acho',
#  'que,por',
#  'mais',
#  'improvável',
#  'que',
#  'seja,por',
#  'macho,',
#  'acho',
#  'que',
#  'só',
#  'a',
#  'punchline',
#  'esta',
#  'pois',
#  'a',
#  'harley',
#  'esta',
#  'tentando',
#  'matar',
#  'o',
#  'coringa',
#  'e',
#  'não',
#  'está',
#  'brigando',
#  'com',
#  'a',
#  'punch',
#  'por',
#  'ele,mais',
#  'a',
#  'punch',
#  'eu',
#  'já',
#  'não',
#  'sei',
#  'pois',
#  'ela',
#  'provavelmente',
#  'está',
#  'defendendo',
#  'o',
#  'joker',
#  '_s',
#  'o',
#  'brasil',
#  'possui',
#  '23.102',
#  'km',
#  'de',
#  'fronteiras,',
#  'sendo',
#  '15.735',
#  'km',
#  'terrestres',
#  'e',
#  '7.367',
#  'km',
#  'marítimas.',
#  'ahahahahhahahahahah',
#  'de',
#  'novo',
#  'seu',
#  'argumento',
#  'não',
#  'deu.',
#  'o',
#  'que',
#  'o',
#  'brasil',
#  'tem',
#  'de',
#  'fronteira',
#  'a',
#  'itália',
#  'não',
#  'tem',
#  'de',
#  'dimensão',
#  'vendo',
#  'hobbs',
#  'and',
#  'shaw',
#  'pela',
#  'milésima',
#  'vez',
#  'filme',
#  'de',
#  'macho',
#  'de',
#  'qualidade,',
#  'o',
#  'soco',
#  'no',
#  'joker',
#  '__m',
#  'toma',
#  'kit',
#  'island',
#  'e',
#  'joker',
#  'tá',
#  'imune',
#  'rt',
#  ':',
#  'ahnnn...',
#  'eu',
#  'nao',
#  'posso',
#  'fazê',
#  'mais',
#  'nada...',
#  'tô',
#  'ficando',
#  'velho,',
#  'tô',
#  'acabado,',
#  'meu',
#  'pinto',
#  'não',
#  'sobe',
#  'mais...',
#  'eu',
#  'preciso',
#  'fazê',
#  'alguma…',
#  'esquerda',
#  'e',
#  'seu',
#  'amor',
#  'ao',
#  'próximo',
#  'mandetta',
#  'é',
#  'outro',
#  'vendido',
#  'joker...não',
#  'se',
#  'salva',
#  'um',
#  '...',
#  'olhei',
#  'joker',
#  'e',
#  'cara,',
#  'que',
#  'filme',
#  'foda!',
#  'depois',
#  'de',
#  'ver',
#  'joker',
#  ':',
#  '"',
#  'é',
#  'a',
#  'vida',
#  '"',
#  '_joker',
#  '_s',
#  'quando',
#  'bolsonaro',
#  'convoca',
#  'o',
#  'povo',
#  'às',
#  'ruas,',
#  'diz',
#  'pra',
#  'continuar',
#  'indo',
#  'à',
#  'missa,',
#  'ao',
#  'futebol,',
#  'ele',
#  'está',
#  'sim',
#  'sendo',
#  'irresponsável.',
#  'quando',
#  'ele,',
#  'com',
#  'suspeita',
#  'de',
#  'contágio',
#  'e',
#  'se',
#  'recusando',
#  'a',
#  'mostrar',
#  'os',
#  'testes,',
#  'sai',
#  'às',
#  'ruas',
#  'cumprimentando',
#  'as',
#  'pessoas',
#  'que',
#  'ele',
#  'chamou',
#  'ali,',
#  'está',
#  'errado.',
#  'rt',
#  '__:',
#  'taroq',
#  'jamil',
#  '@',
#  'isso',
#  'é',
#  'carbo',
#  'e',
#  'vitamina',
#  'vc',
#  'precisava',
#  'come',
#  'alguma',
#  'proteína',
#  'peixe,bife,frango',
#  'ou',
#  'ovo.',
#  'mais',
#  'mal',
#  'faz',
#  'não',
#  '_bsa',
#  'parece',
#  'verídico.',
#  'o',
#  'joker',
#  'tinha',
#  'razão...',
#  'tenta',
#  'de',
#  'novo',
#  'nobre',
#  'asno',
#  'tava',
#  'procurando',
#  'o',
#  'filme',
#  'do',
#  'joker',
#  'pra',
#  'baixar',
#  'e',
#  'assistir',
#  'com',
#  'meu',
#  'pai',
#  'e',
#  'não',
#  'tava',
#  'achando',
#  'site,',
#  'takei',
#  'o',
#  'fodase',
#  'e',
#  'baixei',
#  'no',
#  'xvideos',
#  '👍',
#  'pessoas',
#  'que',
#  'ouvem',
#  'the',
#  'weeknd',
#  'tem',
#  'um',
#  'lado',
#  'obscuro',
#  '😫',
#  'e',
#  'preferem',
#  'o',
#  'joker',
#  'a',
#  'parasite',
#  'porque',
#  'se',
#  'identificam-se',
#  'bue',
#  'com',
#  'o',
#  'filme',
#  '😔😔',
#  'booooa',
#  'jogador',
#  'ai',
#  'eu',
#  'vi',
#  'mesmo',
#  'fodaaas',
#  'rt',
#  ':',
#  '_seeni',
#  '_rdx2',
#  '_v3',
#  '_joker_ak_7…',
#  'o',
#  'melhor',
#  'é',
#  'que',
#  'la',
#  'fora',
#  'ninguém',
#  'entende',
#  'a',
#  'piada,',
#  'pq',
#  'o',
#  'filme',
#  'se',
#  'chama',
#  'joker!',
#  'k',
#  'asco',
#  'me',
#  'da',
#  'le',
#  'parece',
#  'al',
#  'joker',
#  '_s',
#  'serve',
#  'essa',
#  '?',
#  'se',
#  'quiser',
#  'mais',
#  'olha',
#  'no',
#  'google',
#  'minha',
#  'filha,',
#  'vc',
#  'já',
#  'ouviu',
#  'falar',
#  '"vai',
#  'quem',
#  'quer?"',
#  'eu',
#  'n',
#  'posso',
#  'ir',
#  'na',
#  'igreja',
#  'orar',
#  'mas',
#  'tenho',
#  'que',
#  'pegar',
#  'ônibus',
#  'lotado',
#  'com',
#  'neguinho',
#  'respirando',
#  'no',
#  'meu',
#  'cangote',
#  '?',
#  'muita',
#  'lógica',
#  'né',
#  '?',
#  'rt',
#  ':',
#  'parece',
#  'que',
#  '#joker',
#  'também',
#  'continua',
#  'em',
#  'cartaz',
#  'em',
#  'laguns',
#  'cinemas',
#  'do',
#  'japão🇯🇵...é',
#  'bom',
#  'sair',
#  'da',
#  'sessao',
#  'de',
#  'um',
#  'e',
#  'entrar',
#  'para',
#  'a…',
#  'rt',
#  ':',
#  '"well...',
#  'the',
#  'joker',
#  'is',
#  'called',
#  'the',
#  'coringa',
#  'in',
#  'brazil"',
#  'meu',
#  'amigo',
#  'daí',
#  'o',
#  'salto',
#  'que',
#  'eu',
#  'tenho',
#  'qje',
#  'fazer',
#  'e',
#  'o',
#  'nível',
#  'de',
#  'abstração…',
#  '_joker',
#  ...]

# %%
print('Número de palavras diferentes na base de treinamento inteira:', len(palavras_total))
# Out:
# Número de palavras diferentes na base de treinamento inteira: 5057

# %% [markdown]
# Fazendo uma breve análise dos 15 termos mais frequentes, observa-se que alguns desses termos não são significantes para a nossa análise, e portanto deve-se ser feita a limpeza para nao prejudicar o resultado/performance. Exemplo:
# - https
# - -
# - rt
# - /
# - @

# %%
def Frequencia(n):
    y = cleanup(' '.join(excel[excel.Etiquetas==n].Treinamento)).split() #y é uma lista com todas as palavras de cada categoria
    f_rel = pd.Series(y).value_counts(True)
    f_abs = pd.Series(y).value_counts()
    prob = len(y)/len(texto_completo)
    return y,f_rel,f_abs,prob

# %% [markdown]
# ### Definindo a probabilidade de cada uma das categorias

# %%
fig = plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
t3 = pd.Series(excel.Etiquetas).value_counts(True).sort_index()
t3.plot(kind='bar')
plt.title('F.rel por categoria base de Treinamento')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')


plt.subplot(1, 2, 2)
t4 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
t4.plot(kind='bar')
plt.title('F.rel por categoria base de Teste')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')

plt.show()

# %%
ct1 = pd.Series(excel_teste.Etiquetas).value_counts(True).sort_index()
ct1.plot(kind='bar')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')
plt.show()
ct1.to_frame()
# Out:
#    Etiquetas
# D   0.275168
# F   0.724832

# %% [markdown]
# Aqui, ainda utilizando a funcao anterior que além de limpar a base, retorna as frequencias de cada uma das categorias, podemos definir as seguintes probabilidades:

# %%
d, rel_d, abs_d, prob_d = Frequencia('D')
f, rel_f, abs_f, prob_f = Frequencia('F')

#Definindo as probabilidades: soma = 1
prob_f = len(f)/len(d + f)
rel_d.head(15)
# Out:
# joker    0.039084
# o        0.032233
# de       0.025070
# a        0.022111
# e        0.022111
# que      0.020399
# do       0.017751
# é        0.014793
# eu       0.012146
# não      0.009031
# filme    0.008720
# pra      0.008253
# rt       0.008253
# com      0.007630
# um       0.007630
# dtype: float64

# %%
print('Número de palavras diferentes na base de treinamento inteira:', len(rel_d+rel_f))
# Out:
# Número de palavras diferentes na base de treinamento inteira: 5057

# %%
def calcula_prob(n):
    alpha = 1
    y,f_rel,f_abs,prob = Frequencia(n)
    probTweetDadoN = []
    probNDadoTweet = []
    for t in excel_teste.Treinamento: #teste aq pq vou classificar pra depois comparar
        PTweetDadoN = 1 #para funcionar o loop que vai multiplicar todas as prob de cada palavra dado a cat
        tweet = cleanup(t).split()
        num_pal_pos = len(f_abs) #numero de palavras possiveis na categoria n 
        num_pal_tot = len(rel_d+rel_f) #numero total de palavras na base de treinamento inteira
        for p in tweet:
            if p in f_rel:
                f_abs_cat = f_abs[p] # quantas vezes a palavra aparece no treino
            else: # se a palavra nao tiver na base de treino freq abs é igual a zero
                f_abs_cat = 0
            PPalavraDadoN = (alpha+f_abs_cat)/(num_pal_pos+num_pal_tot) #probabilidade da palavra dado a categoria #elevei a 2 para as probabilidades nao ficarem mt pequenas
            PTweetDadoN = PTweetDadoN * PPalavraDadoN
        PNDadoTweet = prob*PTweetDadoN
        probTweetDadoN.append(PTweetDadoN) #add a probabilidade de cada tweet dado determinada categoria. 
        probNDadoTweet.append(PNDadoTweet)#Como estamos analisando uma mesma coluna, o len da lista de ambas as categorias vai ser igual, é tranquilo fazer uma lista
    return probTweetDadoN, probNDadoTweet

# %%
probTweetDadoD, probDDadoTweet= calcula_prob('D')
probTweetDadoF, probFDadoTweet = calcula_prob('F')
probDDadoTweet, probFDadoTweet
# Out:
# ([1.280996537051818e-76,
#   2.1128214524950394e-103,
#   2.6877858283734346e-29,
#   4.875677117780953e-120,
#   1.574214470746109e-57,
#   6.751593993554633e-19,
#   3.0594370219299774e-12,
#   1.5818469584263675e-30,
#   2.857720302713557e-63,
#   3.6538794863506707e-28,
#   6.4441130613628816e-43,
#   2.3265654343396265e-39,
#   8.52987146152306e-27,
#   3.1919579767845944e-131,
#   3.0932202967067985e-60,
#   3.348827261325012e-31,
#   5.5754401151023656e-05,
#   2.240929898916738e-42,
#   3.184734793197551e-94,
#   3.384486360289416e-82,
#   4.965275123500099e-15,
#   1.910709520524711e-25,
#   1.2490375258901955e-32,
#   9.860195824017137e-71,
#   2.2363703348561717e-30,
#   5.954610132051049e-37,
#   1.4956310837665338e-40,
#   3.3717695238330536e-39,
#   1.1345746815532488e-16,
#   8.016665271553087e-38,
#   2.2067889437778216e-15,
#   2.0214646462069193e-50,
#   1.2999054694274711e-33,
#   8.516223667184623e-25,
#   4.873738829422953e-151,
#   3.583518729750745e-142,
#   3.436525618962369e-55,
#   1.2895627051624132e-117,
#   4.029165639843196e-18,
#   1.0314259029907068e-73,
#   2.6230260382578342e-23,
#   6.849611604927957e-66,
#   9.905473022950537e-54,
#   1.0422565891888947e-51,
#   7.558624430538253e-76,
#   8.815654091322834e-20,
#   1.0198123406433257e-12,
#   6.781739254329363e-25,
#   1.4824419668738562e-77,
#   6.2065939043751226e-15,
#   3.471031662436919e-31,
#   4.52429546803005e-08,
#   9.209741378124003e-16,
#   3.2624910239544053e-51,
#   6.291785835383931e-113,
#   1.3869505306297732e-35,
#   4.700693246483729e-18,
#   7.209030730715101e-54,
#   2.1349188682071365e-67,
#   1.5545362623181284e-60,
#   8.303209768357409e-29,
#   1.0545353786890812e-41,
#   8.937495222300177e-13,
#   9.906438407878344e-32,
#   1.678185390188984e-29,
#   1.443410220808446e-27,
#   1.365450658962527e-14,
#   6.278732234398022e-169,
#   2.7677967107292832e-30,
#   2.193656848359073e-17,
#   4.1528339276102283e-53,
#   2.1666483202968822e-68,
#   4.650659155397744e-50,
#   3.255401665318718e-36,
#   2.6624518839988005e-29,
#   7.526663194142335e-52,
#   4.139982575291528e-127,
#   1.6753783884946176e-135,
#   1.5742483484478128e-47,
#   1.764786037663232e-55,
#   1.8846948778629037e-59,
#   4.2627669238440744e-27,
#   1.50809848934335e-08,
#   7.385332148269702e-145,
#   5.964288478348318e-10,
#   1.4895825370500296e-14,
#   4.3149946518562774e-45,
#   9.434022734650186e-14,
#   9.0485909360601e-08,
#   9.0485909360601e-08,
#   1.7884069701087712e-23,
#   1.9574213929284624e-43,
#   1.9819563162052934e-25,
#   2.100395548685438e-24,
#   2.2699011543688244e-23,
#   1.2404607178220952e-17,
#   5.924191491456654e-40,
#   3.1415678513455747e-30,
#   8.814925636640316e-40,
#   2.398289899728939e-54,
#   6.492428926917568e-83,
#   5.104523283559886e-50,
#   5.518921432502883e-27,
#   8.303569704656636e-49,
#   4.739681526342348e-35,
#   1.2646592145769165e-20,
#   4.224652772524999e-24,
#   2.7000637880626737e-37,
#   3.4627713478140286e-58,
#   4.804357537317852e-87,
#   1.0427077759350209e-13,
#   1.8478856129556902e-134,
#   2.0587422736356985e-25,
#   1.11078373514864e-45,
#   1.3177346659090002e-65,
#   1.2050189830271781e-17,
#   8.490019902054824e-23,
#   2.550069278052808e-66,
#   3.8702659987717315e-150,
#   6.285498398155385e-14,
#   3.942264595323059e-12,
#   4.173440103634572e-45,
#   2.307241401548028e-31,
#   1.8424522356889808e-25,
#   1.61709129686807e-73,
#   4.150647778342802e-31,
#   3.7595821004833234e-42,
#   1.10033619656236e-28,
#   1.8457931212384225e-31,
#   3.537827902681169e-122,
#   1.6424921826651497e-27,
#   6.834892214943524e-35,
#   1.371709232988465e-45,
#   1.1145422014610927e-106,
#   9.693060665438454e-95,
#   3.70736310550934e-29,
#   5.45325822561369e-84,
#   2.8365326104496104e-15,
#   1.3693862394054759e-62,
#   8.387556917240421e-135,
#   2.2384253554684422e-19,
#   1.804510200126337e-72,
#   3.073383759850892e-22,
#   2.2206793458882837e-25,
#   3.60734559442008e-40,
#   1.5800606320980151e-40,
#   2.1048955300245178e-29,
#   5.520797814263902e-41,
#   1.7693704267928598e-94,
#   1.7223928381657678e-33,
#   2.0135629649261978e-63,
#   9.96503939466724e-21,
#   2.336025754719377e-77,
#   7.386803673045858e-18,
#   5.492830626131918e-19,
#   5.958330148200117e-14,
#   2.6365587005433217e-17,
#   2.4326651480860557e-80,
#   6.7611027808668645e-115,
#   5.836888682662693e-23,
#   6.7188307185672225e-77,
#   4.3411329696626985e-34,
#   1.0724994266760214e-12,
#   1.310188256489942e-25,
#   5.56621711973827e-110,
#   5.351777810546341e-74,
#   1.9735220052281213e-25,
#   2.695439381841287e-26,
#   4.007770781382034e-42,
#   5.316750225988807e-40,
#   3.745151370951598e-55,
#   2.6433535869475005e-09,
#   3.1539267481817676e-42,
#   9.059513188702835e-64,
#   7.9554316301592355e-112,
#   1.1081684949691914e-123,
#   1.1206447354487365e-22,
#   1.3521615920669036e-25,
#   1.9380827773003438e-29,
#   2.873855844788993e-75,
#   6.712518768046843e-36,
#   2.711433497773859e-39,
#   5.251718929490431e-37,
#   3.343359248182041e-79,
#   1.9588431217382506e-89,
#   1.713763155353159e-16,
#   4.000008558469166e-48,
#   6.774114285335863e-58,
#   7.589367599756106e-58,
#   1.5524082915307174e-22,
#   8.676749509565363e-114,
#   1.419370611197437e-23,
#   7.310518136931495e-14,
#   3.4707984297731076e-45,
#   0.00027877200575511827,
#   3.807561529651821e-15,
#   5.2496912481467464e-42,
#   6.84795095872678e-78,
#   1.2788171291140876e-100,
#   7.235888878157784e-16,
#   5.561108138320111e-13,
#   1.0943507816537464e-24,
#   2.4949036896985905e-53,
#   4.841413211896112e-40,
#   3.1952305988846948e-80,
#   6.228214163102822e-33,
#   5.908677396965117e-13,
#   1.7018147193401003e-138,
#   1.3890847548473748e-73,
#   2.4938146014887903e-130,
#   1.92765103891569e-48,
#   1.3922053640468777e-58,
#   3.443756251426235e-26,
#   4.421885365653555e-25,
#   1.0063517046583727e-128,
#   1.5960169986547946e-24,
#   1.711269345664174e-41,
#   5.31617752730358e-36,
#   2.2120076613988263e-63,
#   6.709100264775417e-18,
#   1.7892865435044958e-10,
#   1.7320789333735126e-62,
#   5.812930341666957e-11,
#   4.3061893602424857e-107,
#   6.079927940962645e-126,
#   4.4653467667243056e-21,
#   1.3159839841152766e-82,
#   3.3690337148444515e-55,
#   3.4122898432953896e-115,
#   8.228137233902684e-82,
#   1.6158963388187836e-133,
#   1.1200513119979723e-126,
#   1.4838560223482638e-68,
#   2.5541760352107956e-23,
#   3.7932736322783053e-47,
#   1.4175944128958262e-133,
#   1.8795541878776063e-52,
#   4.0635918307546397e-41,
#   2.4268682584376017e-19,
#   1.9503873427459873e-42,
#   3.675761566583902e-58,
#   8.793373143742283e-64,
#   4.1507772229700575e-119,
#   1.6062640400849843e-48,
#   1.1604856003916277e-22,
#   7.54049244671675e-09,
#   1.5708936143130204e-23,
#   7.54049244671675e-09,
#   2.4995171447775448e-78,
#   1.8808521576353676e-71,
#   4.2899977067040856e-12,
#   9.526728952510294e-25,
#   1.0263776295338251e-24,
#   9.66229348107594e-69,
#   1.3632926380228556e-68,
#   2.8232588229056556e-80,
#   4.904313059046358e-21,
#   1.8356622131579866e-10,
#   7.358386778198918e-41,
#   3.7946901931060944e-60,
#   2.400580049367029e-78,
#   2.3901240557095103e-61,
#   8.138087105195237e-25,
#   9.126445168462766e-34,
#   1.9793738496201e-31,
#   3.8758689445914265e-59,
#   3.3083588250305204e-77,
#   4.025894722885115e-09,
#   6.054707480304144e-23,
#   1.2084227377490224e-17,
#   7.709781295263544e-10,
#   2.061581373781219e-146,
#   7.535265838143736e-26,
#   2.796348398468241e-13,
#   2.623600153750265e-23,
#   2.1851870912667315e-66,
#   5.006532045687377e-61,
#   8.190269839912064e-141,
#   1.5354850395129356e-106,
#   3.532533094849869e-118,
#   4.21538608344076e-28,
#   2.1382387536806006e-149,
#   4.1377292695834156e-15,
#   1.891151933182712e-20,
#   6.12003300209472e-59,
#   1.0094864611504453e-55,
#   1.223774808771991e-11,
#   1.1587186479381926e-29,
#   1.296884343861727e-232,
#   1.0595830040970876e-28,
#   2.1013054939393115e-24,
#   7.019944779006952e-63,
#   6.198035364366078e-79,
#   1.2353093885152384e-57,
#   1.4393965464391378e-83,
#   4.28421969159342e-86,
#   3.411948584609224e-28,
#   2.8472208141107596e-35],
#  [2.710735768068974e-83,
#   4.496164817319649e-109,
#   1.2508653950003095e-27,
#   1.1376793336232738e-117,
#   2.9421044697039484e-60,
#   6.469825618294627e-19,
#   2.7310006293309993e-12,
#   5.997075787877627e-32,
#   5.329708095125203e-68,
#   4.059659355235849e-29,
#   8.260217906845466e-37,
#   5.8369556744876446e-39,
#   9.396475309325384e-26,
#   1.5955939200308235e-132,
#   3.178446501186076e-62,
#   1.3695534014743593e-30,
#   0.0001360064694872917,
#   1.038807551405215e-42,
#   1.6345586176864057e-89,
#   2.679132457341341e-79,
#   3.096587546852227e-14,
#   2.8043222438422096e-25,
#   6.194683516999917e-32,
#   9.251256950686333e-69,
#   2.806623675255919e-31,
#   1.400861325387846e-37,
#   3.020513007456674e-41,
#   5.252844157840863e-40,
#   4.139717921865817e-17,
#   5.699387578576921e-37,
#   5.2663053517895004e-15,
#   1.2969828690872875e-47,
#   1.9692981130148302e-34,
#   6.289113127172086e-24,
#   4.890506001090254e-148,
#   4.255606873644048e-142,
#   4.749758998358503e-57,
#   4.487683406100201e-125,
#   9.359070947991058e-18,
#   1.452299473582601e-77,
#   6.482957615179671e-24,
#   9.512236413658446e-64,
#   6.576354965835039e-54,
#   9.546967758505274e-50,
#   8.877532369721783e-77,
#   1.7958387394780661e-19,
#   9.103335431103332e-13,
#   1.5676505294809352e-24,
#   2.2402201036445155e-77,
#   6.42489252918319e-15,
#   2.2590765458606575e-32,
#   4.7208076878615655e-08,
#   1.9685200803398137e-16,
#   6.810055910854454e-50,
#   7.623703794533256e-110,
#   5.5104438340618386e-36,
#   5.118241924682611e-18,
#   1.29752976279475e-55,
#   1.0013060423212655e-65,
#   1.1175958991168532e-59,
#   2.1430363781324016e-29,
#   2.9922184165617545e-43,
#   1.2165165362633745e-13,
#   3.255079341964839e-32,
#   2.298831425253699e-29,
#   7.564037598592082e-27,
#   2.8438048899663306e-14,
#   7.901922969186113e-163,
#   3.223864575506566e-30,
#   2.0268238021743145e-16,
#   2.4928513170933668e-48,
#   2.1400986296855566e-69,
#   5.4725235352895265e-49,
#   2.743127000801635e-38,
#   2.8505768413130594e-29,
#   2.3237986014391135e-50,
#   1.502318068272253e-126,
#   4.6742545025355566e-127,
#   1.998432763638602e-45,
#   1.203787261038981e-49,
#   2.4541983741710867e-57,
#   4.8888032643425576e-26,
#   8.654814094412871e-08,
#   5.672076930371665e-150,
#   1.1413136958398207e-11,
#   4.3815660526888644e-14,
#   3.849439845597178e-46,
#   6.572349079033296e-14,
#   6.215730122351062e-07,
#   6.215730122351062e-07,
#   4.17947391362702e-24,
#   2.2679352610912534e-40,
#   2.4798402259703574e-25,
#   1.3942999039722928e-24,
#   1.712213985271135e-23,
#   1.367301771308069e-17,
#   2.8307264470484955e-40,
#   1.1168283247018373e-29,
#   1.440773053153488e-38,
#   1.8712965480969936e-51,
#   3.874070472421736e-81,
#   1.6624140794994915e-49,
#   4.0122286392531916e-25,
#   2.7094476192560377e-48,
#   2.075203974969744e-34,
#   8.308246012564138e-20,
#   6.273666599559536e-25,
#   9.995197146428466e-41,
#   4.906503646839069e-58,
#   4.4730244492865354e-87,
#   4.42369649550318e-14,
#   5.727130417457708e-146,
#   5.962434854890192e-25,
#   7.95644074672369e-45,
#   1.0573888502148091e-63,
#   5.75339137495513e-16,
#   3.450268277642913e-24,
#   9.021223414367084e-67,
#   7.135624646484915e-141,
#   8.242416795508876e-14,
#   1.1089797143048308e-12,
#   2.595690449436659e-46,
#   3.329481156405067e-27,
#   1.082004131868818e-22,
#   3.435863941920969e-69,
#   1.7196269392738236e-31,
#   5.664843656373806e-42,
#   1.2930330795754862e-28,
#   3.0199375568299922e-31,
#   1.052080003938041e-115,
#   2.4798155397305107e-29,
#   3.8044772162948896e-34,
#   1.0349672824254216e-42,
#   1.5830295603369172e-108,
#   2.152145401325394e-97,
#   1.0312525955952106e-28,
#   3.1643439594193582e-84,
#   5.870262773418168e-14,
#   1.5960502479327638e-63,
#   1.391799006876651e-137,
#   1.925433866904411e-18,
#   2.5104449362186048e-70,
#   1.5431253334627731e-24,
#   9.405978647153475e-26,
#   6.838385685564851e-39,
#   6.978761897105727e-39,
#   7.487577080186389e-30,
#   1.7919920362117324e-40,
#   3.3209521891715173e-90,
#   1.2952784447594765e-32,
#   2.156758111831704e-62,
#   5.7526396403103674e-21,
#   3.4763676359077535e-71,
#   8.774129013741616e-18,
#   1.0736286716938068e-18,
#   7.488686210244671e-13,
#   7.514808518364261e-17,
#   1.8104762269862658e-75,
#   3.4426592235427633e-116,
#   3.6802861628191086e-23,
#   1.402838645813542e-76,
#   1.4852526166575335e-34,
#   5.940392436818556e-12,
#   1.3918529051938227e-24,
#   3.641557008109421e-101,
#   1.733530250477737e-74,
#   2.9759853856278894e-24,
#   3.327918338719406e-24,
#   1.0228550904009835e-42,
#   1.7576393793333715e-40,
#   8.655611833482253e-57,
#   6.4178514789278475e-09,
#   3.2034578525019865e-44,
#   4.762022293908435e-64,
#   4.364511638150049e-105,
#   1.842703137857341e-135,
#   5.2091825508684156e-23,
#   2.877622999464379e-26,
#   3.6964035695599105e-28,
#   1.7270458642489563e-78,
#   3.141470183012314e-36,
#   3.3723191860887456e-40,
#   6.968759549843363e-37,
#   1.5998223398042749e-75,
#   8.181428087510745e-84,
#   1.018674043600489e-16,
#   1.0104718631312821e-46,
#   1.5369719870117905e-55,
#   1.6170675462845229e-59,
#   8.115946407588052e-23,
#   2.34324779620758e-117,
#   9.553083231147474e-24,
#   5.911569423008414e-16,
#   1.917347495477844e-39,
#   0.0006800323474364585,
#   4.990285876565545e-17,
#   1.2370988567454427e-42,
#   8.374791162791972e-79,
#   1.0801394142071538e-96,
#   1.176171165235175e-16,
#   7.962653691905726e-13,
#   5.983118086459931e-25,
#   1.5624983553302632e-54,
#   1.6488285524689281e-41,
#   3.8725370212988806e-79,
#   5.1205822481144996e-33,
#   8.626208166231202e-13,
#   3.4551750593150756e-143,
#   8.749851912992882e-72,
#   5.3676943598858245e-133,
#   7.031522686876563e-48,
#   7.807798584529326e-62,
#   2.3334451603294663e-26,
#   8.461721775949787e-24,
#   2.2980775738716587e-124,
#   2.6582493317339906e-24,
#   4.9755504733645293e-42,
#   7.012133331614336e-36,
#   1.4401141542468397e-61,
#   3.7520746077506677e-19,
#   1.2040195936635782e-10,
#   1.4576260389788542e-61,
#   6.736468219016465e-11,
#   8.642273301935139e-104,
#   8.22213372211207e-128,
#   2.7060416868019964e-18,
#   7.991585909175436e-79,
#   1.482364226432713e-55,
#   9.276582575372771e-113,
#   1.2163841980441172e-82,
#   5.954082471974404e-148,
#   8.737334149039408e-128,
#   2.923945178639721e-65,
#   1.0445058027807896e-23,
#   1.0018823009449851e-45,
#   7.176292485952901e-138,
#   1.3697216427317064e-51,
#   2.2400494892303267e-38,
#   4.814419590585238e-19,
#   2.7728777441266785e-42,
#   5.628505425177136e-59,
#   1.0969774097632137e-61,
#   2.2513665425534424e-120,
#   3.3323730281190406e-49,
#   8.207663204454586e-20,
#   7.86801281310261e-09,
#   1.0850176611181525e-23,
#   7.86801281310261e-09,
#   1.0887647438182876e-76,
#   3.3167779577291844e-66,
#   2.227647163806958e-12,
#   3.863704335286346e-24,
#   9.715915923760143e-23,
#   5.912694799129077e-69,
#   5.891624617149222e-71,
#   1.6109239363965516e-78,
#   6.799112468996238e-20,
#   1.2944942983028939e-09,
#   8.583513330759033e-37,
#   5.582404157354729e-63,
#   6.831225002624484e-79,
#   4.431221824910339e-60,
#   1.453080704688211e-23,
#   1.3205843477080182e-33,
#   2.1963735664511407e-32,
#   5.4722040536541146e-55,
#   1.4462344259107873e-79,
#   1.3182173186949928e-09,
#   1.1138689499620565e-22,
#   2.9798673336807706e-18,
#   9.558502202658496e-11,
#   2.93633244225443e-162,
#   6.083818225049418e-25,
#   1.0740118854753991e-13,
#   2.4660855388137065e-22,
#   1.8218129111962957e-66,
#   1.7711453134121394e-57,
#   8.490450469066543e-139,
#   8.622723727862033e-109,
#   9.269830822814679e-113,
#   4.9306764726896e-27,
#   2.352940732109648e-149,
#   2.502548303170371e-13,
#   1.0945631083994382e-19,
#   1.4632156106200853e-59,
#   1.0989705774026931e-55,
#   7.191634990571632e-11,
#   5.792444079661452e-29,
#   3.208607554919067e-233,
#   2.19251218334303e-31,
#   6.482425023254497e-25,
#   9.352982302107166e-62,
#   2.317331027820206e-76,
#   1.8979224684268835e-62,
#   1.0198812830599044e-83,
#   2.1203688513729115e-83,
#   8.809195602492547e-27,
#   3.9262884748955436e-35])

# %% [markdown]
# tenho uma lista com a probabilidade de cada tweet pra cada categoria, logo probDDadoTweet[i] é correspondente a probFDadoTweet[i]

# %%
len(excel_teste)
# Out:
# 298

# %%
len(probDDadoTweet)
# Out:
# 298

# %%
class_tweet = []
for i in range(len(excel_teste)):
    if probDDadoTweet[i]>probFDadoTweet[i]:
        class_tweet.append('D')
    else:
        class_tweet.append('F')


excel_teste['class_auto'] = class_tweet
excel_teste.head()
# Out:
#                                          Treinamento Etiquetas class_auto
# 0  rt @_dcbrasil: maior ato do cinema de 2019! \n...         D          D
# 1  eu ñ fui assistir joker no cinema aqui pq so t...         D          D
# 2  @dracoh8 @caiquecerq @mateuscrz098 @joker_bsa ...         F          F
# 3  @joker_bsa @mitofaztd @portalprior mas o prior...         F          F
# 4  rt @itzguk: kpopper atacando o bts por tudo e ...         F          D

# %% [markdown]
# ### ETAPA 6 - Verificando a performance do classificador
#
#
# Nesta etapa, iremos verificar a acurácia do nosso classificador. No gráfico a seguir é possível observar como se comporta a classificacao do nosso classificador

# %%
ct1 = pd.Series(excel_teste.class_auto).value_counts(True).sort_index()
ct1.plot(kind='bar')
plt.ylabel('Frequência Relativa')
plt.xlabel('Categorias')
plt.show()
ct1.to_frame()
# Out:
#    class_auto
# D    0.432886
# F    0.567114

# %% [markdown]
#  Uma classificacao correta quer dizer que a categoria definida manualmente é igual a categoria definida pelo nosso classificador. Sendo assim, ao fazer um cruzamento das variáveis etiquetas e class_auto, obtemos a seguinte tabela:

# %%
ct = pd.crosstab(excel_teste.Etiquetas, excel_teste.class_auto)
ct
# Out:
# class_auto   D    F
# Etiquetas
# D           63   19
# F           66  150

# %% [markdown]
# Fazendo uma análise dela, é possivel calcular o numero de acertos e erros do classificador. Sendo que
# - quando class_auto = Etiquetas - significa que ele acertou
# - quando class_auto diferente de Etiquetas - significa que ele errou
#
#
# Logo:

# %%
acertos = ct.D['D'] + ct.F['F']
erros = ct.D['F'] + ct.F['D']
erros, acertos
# Out:
# (85, 213)

# %%
acuracia = acertos*100/(erros+acertos)
print('Acurácia do classificador: {0}%'.format(acuracia.round(3)))
# Out:
# Acurácia do classificador: 71.477%

# %% [markdown]
# ## CONCLUSÃO

# %% [markdown]
# - Faça um comparativo qualitativo sobre os percentuais obtidos para que possa discutir a performance do seu classificador.
# - Explique como são tratadas as mensagens com dupla negação e sarcasmo.
# - Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?
#
#
# Opcionalmente:
#
# - Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
#
# *Ao se utilizar o próprio classificador para gerar mais amostras de treinamento, o classificador acaba ficando
# 'viciado', ou seja, acaba-se por prejudicar os resultados obtidos, e eles acabam não tendo uma qualidade boa.
# Seria o contrário de puxar mais tweets, que melhora a qualidade dos dados e dos resultados, por ter um espaço
# amostral muito maior.*
#
#
#
# - Propor diferentes cenários de uso para o classificador Naive-Bayes. Pense em outros cenários sem intersecção com este projeto.
# - Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer. Indique material de pesquisa sobre o assunto).
